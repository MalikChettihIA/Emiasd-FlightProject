// %% [markdown]
// # Flight Data Pipeline

// %%
%AddJar file:///home/jovyan/work/apps/Emiasd-Flight-Data-Analysis.jar
// Out:
// Starting download from file:///home/jovyan/work/apps/Emiasd-Flight-Data-Analysis.jar
// Finished download of Emiasd-Flight-Data-Analysis.jar
// Using cached version of Emiasd-Flight-Data-Analysis.jar

// %%
import org.apache.spark.sql.SparkSession
import com.flightdelay.config.{AppConfiguration, ConfigurationLoader}
import com.flightdelay.data.loaders.FlightDataLoader

//Env Configuration
val args: Array[String] = Array("juniper")

val spark = SparkSession.builder()
  .config(sc.getConf)
  .getOrCreate()

// Rendre la session Spark implicite
implicit val session = spark
implicit val configuration: AppConfiguration = ConfigurationLoader.loadConfiguration(args)

// Cellule 4: Test
val flightData = FlightDataLoader.loadFromConfiguration(false)
// Out:
// ================================================================================
// [STEP 1][DataLoader] Flight Data Loading - Start
// ================================================================================
//
// Loading from existing Parquet file:
//   - Path: /home/jovyan/work/output/common/data/raw_flights.parquet
//   - Loaded 486133 records from Parquet (optimized)
//
// Schema:
// root
//  |-- FL_DATE: date (nullable = true)
//  |-- OP_CARRIER_AIRLINE_ID: integer (nullable = true)
//  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
//  |-- ORIGIN_AIRPORT_ID: integer (nullable = true)
//  |-- DEST_AIRPORT_ID: integer (nullable = true)
//  |-- CRS_DEP_TIME: integer (nullable = true)
//  |-- ARR_DELAY_NEW: double (nullable = true)
//  |-- CANCELLED: integer (nullable = true)
//  |-- DIVERTED: integer (nullable = true)
//  |-- CRS_ELAPSED_TIME: double (nullable = true)
//  |-- WEATHER_DELAY: double (nullable = true)
//  |-- NAS_DELAY: double (nullable = true)
//
//
// Sample data (10 rows):
// +----------+---------------------+-----------------+-----------------+---------------+------------+-------------+---------+--------+----------------+-------------+---------+
// |   FL_DATE|OP_CARRIER_AIRLINE_ID|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|DEST_AIRPORT_ID|CRS_DEP_TIME|ARR_DELAY_NEW|CANCELLED|DIVERTED|CRS_ELAPSED_TIME|WEATHER_DELAY|NAS_DELAY|
// +----------+---------------------+-----------------+-----------------+---------------+------------+-------------+---------+--------+----------------+-------------+---------+
// |2012-01-01|                20366|             4426|            15370|          12266|         845|          0.0|     NULL|    NULL|            99.0|         NULL|     NULL|
// |2012-01-01|                20366|             4427|            12266|          15370|         858|          0.0|     NULL|    NULL|            88.0|         NULL|     NULL|
// |2012-01-01|                20366|             4427|            15370|          12266|        1051|          0.0|     NULL|    NULL|            89.0|         NULL|     NULL|
// |2012-01-01|                20366|             4428|            12266|          15370|        1125|         31.0|     NULL|    NULL|            87.0|          0.0|      2.0|
// |2012-01-01|                20366|             4428|            15370|          12266|        1319|         21.0|     NULL|    NULL|            96.0|          0.0|      0.0|
// |2012-01-01|                20366|             4429|            12266|          15370|        1328|          0.0|     NULL|    NULL|            94.0|         NULL|     NULL|
// |2012-01-01|                20366|             4429|            15370|          12266|        1527|          0.0|     NULL|    NULL|            97.0|         NULL|     NULL|
// |2012-01-01|                20366|             4430|            12266|          15370|        1449|         10.0|     NULL|    NULL|            89.0|         NULL|     NULL|
// |2012-01-01|                20366|             4430|            15370|          12266|        1643|          0.0|     NULL|    NULL|            98.0|         NULL|     NULL|
// |2012-01-01|                20366|             4431|            12266|          15370|        1920|         55.0|     NULL|    NULL|            91.0|          0.0|      0.0|
// +----------+---------------------+-----------------+-----------------+---------------+------------+-------------+---------+--------+----------------+-------------+---------+
// only showing top 10 rows
// args = Array(juniper)
// spark = org.apache.spark.sql.SparkSession@657c5a35
// session = org.apache.spark.sql.SparkSession@657c5a35
// configuration = AppConfiguration(local,CommonConfig(42,DataConfig(/home/jovyan/work/data,FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Flights/201201.csv),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Weather/201201hourly.txt),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/wban_airport_timezone.csv)),OutputConfig(/home/jovyan/work/output,FileConfig(/home/jovyan/work/output/data),FileCo...
// AppConfiguration(local,CommonConfig(42,DataConfig(/home/jovyan/work/data,FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Flights/201201.csv),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Weather/201201hourly.txt),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/wban_airport_timezone.csv)),OutputConfig(/home/jovyan/work/output,FileConfig(/home/jovyan/work/output/data),FileCo...

// %% [markdown]
// # Data Pipeline

// %%
import com.flightdelay.data.DataPipeline

val dataPipelineDF = DataPipeline.execute()
// Out:
// ================================================================================
// [DataPipeline] Complete Data Pipeline - Start
// ================================================================================
//
// [Step 1/6] Loading raw flight data...
//
// ================================================================================
// [STEP 1][DataLoader] Flight Data Loading - Start
// ================================================================================
//
// Loading from existing Parquet file:
//   - Path: /home/jovyan/work/output/common/data/raw_flights.parquet
//   - Loaded 486133 records from Parquet (optimized)
//
// Schema:
// root
//  |-- FL_DATE: date (nullable = true)
//  |-- OP_CARRIER_AIRLINE_ID: integer (nullable = true)
//  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
//  |-- ORIGIN_AIRPORT_ID: integer (nullable = true)
//  |-- DEST_AIRPORT_ID: integer (nullable = true)
//  |-- CRS_DEP_TIME: integer (nullable = true)
//  |-- ARR_DELAY_NEW: double (nullable = true)
//  |-- CANCELLED: integer (nullable = true)
//  |-- DIVERTED: integer (nullable = true)
//  |-- CRS_ELAPSED_TIME: double (nullable = true)
//  |-- WEATHER_DELAY: double (nullable = true)
//  |-- NAS_DELAY: double (nullable = true)
//
//
// Sample data (10 rows):
// +----------+---------------------+-----------------+-----------------+---------------+------------+-------------+---------+--------+----------------+-------------+---------+
// |   FL_DATE|OP_CARRIER_AIRLINE_ID|OP_CARRIER_FL_NUM|ORIGIN_AIRPORT_ID|DEST_AIRPORT_ID|CRS_DEP_TIME|ARR_DELAY_NEW|CANCELLED|DIVERTED|CRS_ELAPSED_TIME|WEATHER_DELAY|NAS_DELAY|
// +----------+---------------------+-----------------+-----------------+---------------+------------+-------------+---------+--------+----------------+-------------+---------+
// |2012-01-01|                20366|             4426|            15370|          12266|         845|          0.0|     NULL|    NULL|            99.0|         NULL|     NULL|
// |2012-01-01|                20366|             4427|            12266|          15370|         858|          0.0|     NULL|    NULL|            88.0|         NULL|     NULL|
// |2012-01-01|                20366|             4427|            15370|          12266|        1051|          0.0|     NULL|    NULL|            89.0|         NULL|     NULL|
// |2012-01-01|                20366|             4428|            12266|          15370|        1125|         31.0|     NULL|    NULL|            87.0|          0.0|      2.0|
// |2012-01-01|                20366|             4428|            15370|          12266|        1319|         21.0|     NULL|    NULL|            96.0|          0.0|      0.0|
// |2012-01-01|                20366|             4429|            12266|          15370|        1328|          0.0|     NULL|    NULL|            94.0|         NULL|     NULL|
// |2012-01-01|                20366|             4429|            15370|          12266|        1527|          0.0|     NULL|    NULL|            97.0|         NULL|     NULL|
// |2012-01-01|                20366|             4430|            12266|          15370|        1449|         10.0|     NULL|    NULL|            89.0|         NULL|     NULL|
// |2012-01-01|                20366|             4430|            15370|          12266|        1643|          0.0|     NULL|    NULL|            98.0|         NULL|     NULL|
// |2012-01-01|                20366|             4431|            12266|          15370|        1920|         55.0|     NULL|    NULL|            91.0|          0.0|      0.0|
// +----------+---------------------+-----------------+-----------------+---------------+------------+-------------+---------+--------+----------------+-------------+---------+
// only showing top 10 rows
//
// [Step 1/6] Completed in 0.149s
//
// [Step 2/6] Loading raw weather data...
//
// ================================================================================
// [STEP 1][DataLoader] Weather Data Loading - Start
// ================================================================================
//
// Loading from existing Parquet file:
//   - Path: /home/jovyan/work/output/common/data/raw_weather.parquet
//   - Loaded 4192912 records from Parquet (optimized)
//
// Schema:
// root
//  |-- WBAN: string (nullable = true)
//  |-- Date: string (nullable = true)
//  |-- Time: string (nullable = true)
//  |-- StationType: integer (nullable = true)
//  |-- SkyCondition: string (nullable = true)
//  |-- SkyConditionFlag: string (nullable = true)
//  |-- Visibility: double (nullable = true)
//  |-- VisibilityFlag: string (nullable = true)
//  |-- WeatherType: string (nullable = true)
//  |-- WeatherTypeFlag: string (nullable = true)
//  |-- DryBulbFarenheit: double (nullable = true)
//  |-- DryBulbFarenheitFlag: string (nullable = true)
//  |-- DryBulbCelsius: double (nullable = true)
//  |-- DryBulbCelsiusFlag: string (nullable = true)
//  |-- WetBulbFarenheit: double (nullable = true)
//  |-- WetBulbFarenheitFlag: string (nullable = true)
//  |-- WetBulbCelsius: double (nullable = true)
//  |-- WetBulbCelsiusFlag: string (nullable = true)
//  |-- DewPointFarenheit: double (nullable = true)
//  |-- DewPointFarenheitFlag: string (nullable = true)
//  |-- DewPointCelsius: double (nullable = true)
//  |-- DewPointCelsiusFlag: string (nullable = true)
//  |-- RelativeHumidity: double (nullable = true)
//  |-- RelativeHumidityFlag: string (nullable = true)
//  |-- WindSpeed: double (nullable = true)
//  |-- WindSpeedFlag: string (nullable = true)
//  |-- WindDirection: double (nullable = true)
//  |-- WindDirectionFlag: string (nullable = true)
//  |-- ValueForWindCharacter: string (nullable = true)
//  |-- ValueForWindCharacterFlag: string (nullable = true)
//  |-- StationPressure: double (nullable = true)
//  |-- StationPressureFlag: string (nullable = true)
//  |-- PressureTendency: string (nullable = true)
//  |-- PressureTendencyFlag: string (nullable = true)
//  |-- PressureChange: double (nullable = true)
//  |-- PressureChangeFlag: string (nullable = true)
//  |-- SeaLevelPressure: string (nullable = true)
//  |-- SeaLevelPressureFlag: string (nullable = true)
//  |-- RecordType: string (nullable = true)
//  |-- RecordTypeFlag: string (nullable = true)
//  |-- HourlyPrecip: string (nullable = true)
//  |-- HourlyPrecipFlag: string (nullable = true)
//  |-- Altimeter: double (nullable = true)
//  |-- AltimeterFlag: string (nullable = true)
//
//
// Sample data (10 rows):
// +-----+--------+----+-----------+------------+----------------+----------+--------------+-----------+---------------+----------------+--------------------+--------------+------------------+----------------+--------------------+--------------+------------------+-----------------+---------------------+---------------+-------------------+----------------+--------------------+---------+-------------+-------------+-----------------+---------------------+-------------------------+---------------+-------------------+----------------+--------------------+--------------+------------------+----------------+--------------------+----------+--------------+------------+----------------+---------+-------------+
// | WBAN|    Date|Time|StationType|SkyCondition|SkyConditionFlag|Visibility|VisibilityFlag|WeatherType|WeatherTypeFlag|DryBulbFarenheit|DryBulbFarenheitFlag|DryBulbCelsius|DryBulbCelsiusFlag|WetBulbFarenheit|WetBulbFarenheitFlag|WetBulbCelsius|WetBulbCelsiusFlag|DewPointFarenheit|DewPointFarenheitFlag|DewPointCelsius|DewPointCelsiusFlag|RelativeHumidity|RelativeHumidityFlag|WindSpeed|WindSpeedFlag|WindDirection|WindDirectionFlag|ValueForWindCharacter|ValueForWindCharacterFlag|StationPressure|StationPressureFlag|PressureTendency|PressureTendencyFlag|PressureChange|PressureChangeFlag|SeaLevelPressure|SeaLevelPressureFlag|RecordType|RecordTypeFlag|HourlyPrecip|HourlyPrecipFlag|Altimeter|AltimeterFlag|
// +-----+--------+----+-----------+------------+----------------+----------+--------------+-----------+---------------+----------------+--------------------+--------------+------------------+----------------+--------------------+--------------+------------------+-----------------+---------------------+---------------+-------------------+----------------+--------------------+---------+-------------+-------------+-----------------+---------------------+-------------------------+---------------+-------------------+----------------+--------------------+--------------+------------------+----------------+--------------------+----------+--------------+------------+----------------+---------+-------------+
// |03011|20120101|0015|          0|         CLR|                |      10.0|              |           |               |            23.0|                    |          -5.0|                  |            15.0|                    |          -9.5|                  |             -9.0|                     |          -23.0|                   |            24.0|                    |      5.0|             |        120.0|                 |                     |                         |           21.7|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.43|             |
// |03011|20120101|0035|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            14.0|                    |         -10.2|                  |             -9.0|                     |          -23.0|                   |            26.0|                    |      6.0|             |        130.0|                 |                     |                         |           21.7|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.43|             |
// |03011|20120101|0055|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            13.0|                    |         -10.5|                  |            -13.0|                     |          -25.0|                   |            21.0|                    |      0.0|             |          0.0|                 |                     |                         |          21.71|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.44|             |
// |03011|20120101|0115|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            14.0|                    |         -10.1|                  |             -8.0|                     |          -22.0|                   |            27.0|                    |      0.0|             |          0.0|                 |                     |                         |          21.71|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.44|             |
// |03011|20120101|0135|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            13.0|                    |         -10.4|                  |            -11.0|                     |          -24.0|                   |            23.0|                    |      0.0|             |          0.0|                 |                     |                         |          21.72|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.45|             |
// |03011|20120101|0155|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            13.0|                    |         -10.5|                  |            -13.0|                     |          -25.0|                   |            21.0|                    |      6.0|             |        130.0|                 |                     |                         |          21.72|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.45|             |
// |03011|20120101|0215|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            14.0|                    |         -10.2|                  |             -9.0|                     |          -23.0|                   |            26.0|                    |      5.0|             |         90.0|                 |                     |                         |          21.73|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.46|             |
// |03011|20120101|0235|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            14.0|                    |         -10.2|                  |             -9.0|                     |          -23.0|                   |            26.0|                    |      6.0|             |        120.0|                 |                     |                         |          21.74|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.47|             |
// |03011|20120101|0255|          0|         CLR|                |      10.0|              |           |               |            21.0|                    |          -6.0|                  |            13.0|                    |         -10.4|                  |            -11.0|                     |          -24.0|                   |            23.0|                    |      7.0|             |        130.0|                 |                     |                         |          21.74|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.48|             |
// |03011|20120101|0315|          0|         CLR|                |      10.0|              |           |               |            23.0|                    |          -5.0|                  |            15.0|                    |          -9.4|                  |             -8.0|                     |          -22.0|                   |            25.0|                    |      9.0|             |        120.0|                 |                     |                         |          21.74|                   |                |                    |          NULL|                  |               M|                    |        AA|              |            |                |    30.47|             |
// +-----+--------+----+-----------+------------+----------------+----------+--------------+-----------+---------------+----------------+--------------------+--------------+------------------+----------------+--------------------+--------------+------------------+-----------------+---------------------+---------------+-------------------+----------------+--------------------+---------+-------------+-------------+-----------------+---------------------+-------------------------+---------------+-------------------+----------------+--------------------+--------------+------------------+----------------+--------------------+----------+--------------+------------+----------------+---------+-------------+
// only showing top 10 rows
//
// [Step 2/6] Completed in 0.37s
//
// [Step 3/6] Loading WBAN-Airport-Timezone mapping...
//
// ================================================================================
// [STEP 1][DataLoader] WBAN-Airport-Timezone Mapping Loading - Start
// ================================================================================
//
// Loading from existing Parquet file:
//   - Path: /home/jovyan/work/output/common/data/raw_wban_airport_timezone.parquet
//   - Loaded 305 records from Parquet (optimized)
//
// Schema:
// root
//  |-- AirportID: integer (nullable = true)
//  |-- WBAN: string (nullable = true)
//  |-- TimeZone: integer (nullable = true)
//
//
// Sample data (10 rows):
// +---------+-----+--------+
// |AirportID| WBAN|TimeZone|
// +---------+-----+--------+
// |    10685|54831|      -6|
// |    14871|24232|      -8|
// |    10620|24033|      -7|
// |    14747|24233|      -8|
// |    11252|12834|      -5|
// |    14842|23034|      -6|
// |    14771|23234|      -8|
// |    11624|12836|      -5|
// |    12884|14836|      -5|
// |    13024|94236|      -8|
// +---------+-----+--------+
// only showing top 10 rows
//
// [Step 3/6] Completed in 0.166s
//
// [Step 4/6] Preprocessing flight data...
//
// ================================================================================
// [Preprocessing] Flight Data Preprocessing Pipeline - Start
// ================================================================================
//
// Loading raw data from parquet:
//   - Path: /home/jovyan/work/output/common/data/raw_flights.parquet
//   - Loaded 486133 raw records
//
// ================================================================================
// [STEP 2][DataCleaner] Flight Data Cleaning - Start
// ================================================================================
//
// Original dataset: 486133 records
//
// Phase 1: Basic Cleaning
//   - Current count: 486133 records
//
// Phase 2: Filter Invalid Flights
//   - Filtering cancelled and diverted flights
//   - Filtering invalid departure times
//   - Filtering invalid airports
//   - Current count: 486133 records
//
// Phase 3: Data Type Conversion
// Conversion des types de données: NAS_DELAY, OP_CARRIER_AIRLINE_ID, OP_CARRIER_FL_NUM, WEATHER_DELAY, DEST_AIRPORT_ID, ORIGIN_AIRPORT_ID, CRS_ELAPSED_TIME, FL_DATE, CRS_DEP_TIME, ARR_DELAY_NEW
//   - Filtering invalid flight dates
//   - Current count: 486133 records
//
// Phase 4: Outlier Filtering
//   - Filtering delays > 600 minutes
//   - Filtering flight times (10 min - 24 hours)
//   - Current count: 486067 records
//
// Phase 5: Final Validation
//   - Validation passed: 486067 records
//
// ==================================================
// Cleaning Summary
// ==================================================
// Original records:       486,133
// Final records:          486,067
// Removed records:             66
// Reduction:             0%
// ==================================================
//
// ================================================================================
// [Preprocessing] Flight WBAN Enrichment - Start
// ================================================================================
//
// Loading WBAN-Airport-Timezone mapping:
//   - Path: /home/jovyan/work/output/common/data/raw_wban_airport_timezone.parquet
//   - Loaded 305 airport-WBAN mappings
//
//   - Added UTC_CRS_DEP_TIME and UTC_FL_DATE conversion
//   - Handling timezone offsets and date boundaries
//
// Enrichment statistics:
//   - Total flights: 461310
//   - Flights with origin WBAN: 461310 (100%)
//   - Flights with destination WBAN: 461310 (100%)
//
// ================================================================================
// [Preprocessing] Flight WBAN Enrichment - End
// ================================================================================
//
// ================================================================================
// [STEP 2][FlightDataGenerator] Flight Data Generator - Start ...
// ================================================================================
// Original Column Counts: 16
//
// Phase 1: Add Temporal Features
// Temporal features added: 30
//
// Phase 2: Add Flight Characteristics
// Added Flight features: 7
//
// Phase 3: Add Period <indicator
// Added Flight features: 16
//
// Phase 4: Add Geographical Features
// Added Flight features: 8
//
// Phase 5 : Add Aggregated Features
// Added Flight features: 5
//
// === Enrichment Summary ===
//
// Original Columns: 16
// Columns after enrichment: 82
// Enriched Columns: 66
// Dataset size: 461310
//
// New Features Created :
//
// feature_departure_minute,
// feature_flight_days_span,
// feature_arrival_minutes_total,
// feature_crosses_midnight,
// feature_flight_day_of_week,
// feature_departure_hour_decimal,
// feature_flight_timestamp,
// feature_utc_departure_hour,
// feature_flight_quarter_name,
// feature_utc_departure_hour_decimal,
// feature_departure_hour,
// feature_minutes_since_midnight,
// feature_departure_quarter_day,
// feature_flight_month,
// feature_utc_departure_hour_rounded,
// feature_arrival_hour,
// feature_arrival_minute,
// feature_flight_year,
// feature_flight_day_of_year,
// feature_arrival_time,
// feature_flight_quarter,
// feature_arrival_hour_decimal,
// feature_flight_week_of_year,
// feature_flight_day_of_month,
// feature_departure_quarter_name,
// feature_departure_time_period,
// feature_departure_hour_rounded,
// feature_departure_minutes_total,
// feature_arrival_hour_rounded,
// feature_arrival_date,
// feature_distance_score,
// feature_distance_category,
// feature_carrier_hash,
// feature_route_id,
// feature_is_likely_domestic,
// feature_is_roundtrip_candidate,
// feature_flight_unique_id,
// feature_is_summer,
// feature_is_monday,
// feature_is_evening_rush,
// feature_is_month_start,
// feature_is_extended_weekend,
// feature_is_winter,
// feature_is_friday,
// feature_is_spring,
// feature_is_weekend,
// feature_is_holiday_season,
// feature_is_fall,
// feature_is_early_morning,
// feature_is_morning_rush,
// feature_is_business_hours,
// feature_is_night_flight,
// feature_is_month_end,
// feature_origin_complexity_score,
// feature_is_westbound,
// feature_dest_complexity_score,
// feature_dest_is_major_hub,
// feature_is_eastbound,
// feature_timezone_diff_proxy,
// feature_origin_is_major_hub,
// feature_is_hub_to_hub,
// feature_flights_on_route,
// feature_carrier_flight_count,
// feature_origin_airport_traffic,
// feature_route_popularity_score,
// feature_carrier_size_category
//
//
// ================================================================================
// [STEP 2][FlightLabelGenerator] Flight Label Generator - Start ...
// ================================================================================
//
// Phase 1: Validate Required Columns
// - Validation of required columns: OK
//
// Phase 2: Handling missing values for delays
//
// Phase 2: Adding basic labels for different thresholds
//
// ================================================================================
// [Data Balancing] Random Under-Sampling - Start
// ================================================================================
//
// Original dataset distribution:
//   - Total samples:       461,310
//   - Delayed flights:      67,314 (14.59%)
//   - On-time flights:     393,996 (85.41%)
//
// Balancing strategy:
//   - Minority class: delayed (67314 samples)
//   - Majority class: on-time (393996 samples)
//   - Random under-sampling majority class to 67314 samples
//
// Applying random under-sampling:
//   - Sampling fraction: 0.170849
//   - Random seed: 42
//
// Balanced dataset distribution:
//   - Total samples:       135,006
//   - Delayed flights:      67,314 (49.86%)
//   - On-time flights:      67,692 (50.14%)
//   - Reduction ratio:  29.27%
//   - Samples removed:     326,304
// ================================================================================
//
// [Data Balancing] Random Under-Sampling - End
// ================================================================================
//
//
// ================================================================================
// Schema Validation
// ================================================================================
//
// Validating base columns:
//   - OP_CARRIER_AIRLINE_ID (IntegerType)
//   - OP_CARRIER_FL_NUM (IntegerType)
//   - DEST_AIRPORT_ID (IntegerType)
//   - ORIGIN_AIRPORT_ID (IntegerType)
//   - CRS_ELAPSED_TIME (DoubleType)
//   - CRS_DEP_TIME (IntegerType)
//   - UTC_FL_DATE (DateType)
//
// Validating generated columns:
//   - feature_departure_hour
//   - feature_flight_month
//   - feature_flight_year
//   - feature_flight_quarter
//   - feature_flight_day_of_week
//   - feature_is_weekend
//   - feature_route_id
//   - feature_distance_category
//   - ORIGIN_WBAN
//   - ORIGIN_TIMEZONE
//   - DEST_WBAN
//   - DEST_TIMEZONE
//
// Validating label columns:
//   - label_arr_delay_filled
//   - label_weather_delay_filled
//   - label_nas_delay_filled
//   - label_is_delayed_15min
//   - label_is_delayed_30min
//   - label_is_delayed_60min
//   - label_is_delayed_90min
//
// ================================================================================
// - Schema Validation PASSED - 99 columns validated
// ================================================================================
//
// Saving preprocessed data to parquet:
//   - Path: /home/jovyan/work/output/common/data/processed_flights.parquet
//   - Saved 134876 preprocessed records
//
// ================================================================================
// [Preprocessing] Flight Data Preprocessing Pipeline - End
// ================================================================================
//
// [Step 4/6] Completed in 43.744s
//
// [Step 5/6] Preprocessing weather data...
//
// ================================================================================
// [Preprocessing] Weather Data Preprocessing Pipeline - Start
// ================================================================================
//
// Loading raw data from parquet:
//   - Path: /home/jovyan/work/output/common/data/raw_weather.parquet
//   - Loaded 4192912 raw records
//
// Saving preprocessed data to parquet:
//   - Path: /home/jovyan/work/output/common/data/processed_weather.parquet
//   - Saved 4192912 preprocessed records
//
// ================================================================================
// [Preprocessing] Weather Data Preprocessing Pipeline - End
// ================================================================================
//
// [Step 5/6] Completed in 23.108s
//
// [Step 6/6] Joining flight and weather data...
//
// ================================================================================
// [Joiner] Flight-Weather Data Join - Start
// ================================================================================
//
// Input flight data:
//   - Records: 134876
//   - Columns: 99
//
// Input weather data:
//   - Records: 4192912
//   - Columns: 67
//
// Step 1: Preparing weather data with partitioning...
//   - Weather data partitioned by (WBAN, Date)
//
// Step 2: Joining with origin weather observations...
//
//   [Origin Weather Join] Weather columns to join: 64
//     - Weather features: StationType, SkyCondition, SkyConditionFlag, Visibility, VisibilityFlag...
//   [Origin Weather Join] Completed in 0.324s - Created 64 weather arrays
//   - Origin weather joined: 134876 flights
//
// Step 3: Joining with destination weather observations...
//
//   [Destination Weather Join] Weather columns to join: 64
//     - Weather features: StationType, SkyCondition, SkyConditionFlag, Visibility, VisibilityFlag...
//   [Destination Weather Join] Completed in 0.484s - Created 64 weather arrays
//   - Destination weather joined: 134876 flights
//
// Output joined data:
//   - Records: 134876
//   - Columns: 229
//
// ================================================================================
// [Joiner] Flight-Weather Data Join - End
// ================================================================================
//
// [Step 6/6] Completed in 30.452s
//
// ================================================================================
// [DataPipeline] Complete Data Pipeline - End (Total: 97.989s)
// ================================================================================
//
//
// Saving joined flight weather parquet data to parquet:
//   - Path: /home/jovyan/work/output/common/data/joined_flights_weather.parquet
//   - Saved 134876 preprocessed records
// dataPipelineDF = [FL_DATE: date, OP_CARRIER_AIRLINE_ID: int ... 227 more fields]
// [FL_DATE: date, OP_CARRIER_AIRLINE_ID: int ... 227 more fields]

// %%
dataPipelineDF.cache()
dataPipelineDF.count()
// Out:
// 134665

// %%
dataPipelineDF.printSchema
// Out:
// root
//  |-- FL_DATE: date (nullable = true)
//  |-- OP_CARRIER_AIRLINE_ID: integer (nullable = true)
//  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
//  |-- ORIGIN_AIRPORT_ID: integer (nullable = true)
//  |-- DEST_AIRPORT_ID: integer (nullable = true)
//  |-- CRS_DEP_TIME: integer (nullable = true)
//  |-- ARR_DELAY_NEW: double (nullable = true)
//  |-- CRS_ELAPSED_TIME: double (nullable = true)
//  |-- WEATHER_DELAY: double (nullable = true)
//  |-- NAS_DELAY: double (nullable = true)
//  |-- ORIGIN_WBAN: string (nullable = true)
//  |-- ORIGIN_TIMEZONE: integer (nullable = true)
//  |-- DEST_WBAN: string (nullable = true)
//  |-- DEST_TIMEZONE: integer (nullable = true)
//  |-- UTC_CRS_DEP_TIME: string (nullable = true)
//  |-- UTC_FL_DATE: date (nullable = true)
//  |-- feature_departure_minute: integer (nullable = true)
//  |-- feature_flight_days_span: integer (nullable = true)
//  |-- feature_arrival_minutes_total: double (nullable = true)
//  |-- feature_crosses_midnight: integer (nullable = true)
//  |-- feature_flight_day_of_week: integer (nullable = true)
//  |-- feature_departure_hour_decimal: double (nullable = true)
//  |-- feature_flight_timestamp: timestamp (nullable = true)
//  |-- feature_utc_departure_hour: integer (nullable = true)
//  |-- feature_flight_quarter_name: string (nullable = true)
//  |-- feature_utc_departure_hour_decimal: double (nullable = true)
//  |-- feature_departure_hour: integer (nullable = true)
//  |-- feature_minutes_since_midnight: double (nullable = true)
//  |-- feature_departure_quarter_day: integer (nullable = true)
//  |-- feature_flight_month: integer (nullable = true)
//  |-- feature_utc_departure_hour_rounded: long (nullable = true)
//  |-- feature_arrival_hour: integer (nullable = true)
//  |-- feature_arrival_minute: integer (nullable = true)
//  |-- feature_flight_year: integer (nullable = true)
//  |-- feature_flight_day_of_year: integer (nullable = true)
//  |-- feature_arrival_time: integer (nullable = true)
//  |-- feature_flight_quarter: integer (nullable = true)
//  |-- feature_arrival_hour_decimal: double (nullable = true)
//  |-- feature_flight_week_of_year: integer (nullable = true)
//  |-- feature_flight_day_of_month: integer (nullable = true)
//  |-- feature_departure_quarter_name: string (nullable = true)
//  |-- feature_departure_time_period: string (nullable = true)
//  |-- feature_departure_hour_rounded: long (nullable = true)
//  |-- feature_departure_minutes_total: double (nullable = true)
//  |-- feature_arrival_hour_rounded: string (nullable = true)
//  |-- feature_arrival_date: string (nullable = true)
//  |-- feature_distance_score: double (nullable = true)
//  |-- feature_distance_category: string (nullable = true)
//  |-- feature_carrier_hash: integer (nullable = true)
//  |-- feature_route_id: string (nullable = true)
//  |-- feature_is_likely_domestic: integer (nullable = true)
//  |-- feature_is_roundtrip_candidate: integer (nullable = true)
//  |-- feature_flight_unique_id: string (nullable = true)
//  |-- feature_is_summer: integer (nullable = true)
//  |-- feature_is_monday: integer (nullable = true)
//  |-- feature_is_evening_rush: integer (nullable = true)
//  |-- feature_is_month_start: integer (nullable = true)
//  |-- feature_is_extended_weekend: integer (nullable = true)
//  |-- feature_is_winter: integer (nullable = true)
//  |-- feature_is_friday: integer (nullable = true)
//  |-- feature_is_spring: integer (nullable = true)
//  |-- feature_is_weekend: integer (nullable = true)
//  |-- feature_is_holiday_season: integer (nullable = true)
//  |-- feature_is_fall: integer (nullable = true)
//  |-- feature_is_early_morning: integer (nullable = true)
//  |-- feature_is_morning_rush: integer (nullable = true)
//  |-- feature_is_business_hours: integer (nullable = true)
//  |-- feature_is_night_flight: integer (nullable = true)
//  |-- feature_is_month_end: integer (nullable = true)
//  |-- feature_origin_complexity_score: double (nullable = true)
//  |-- feature_is_westbound: integer (nullable = true)
//  |-- feature_dest_complexity_score: double (nullable = true)
//  |-- feature_dest_is_major_hub: integer (nullable = true)
//  |-- feature_is_eastbound: integer (nullable = true)
//  |-- feature_timezone_diff_proxy: integer (nullable = true)
//  |-- feature_origin_is_major_hub: integer (nullable = true)
//  |-- feature_is_hub_to_hub: integer (nullable = true)
//  |-- feature_flights_on_route: long (nullable = true)
//  |-- feature_carrier_flight_count: long (nullable = true)
//  |-- feature_origin_airport_traffic: long (nullable = true)
//  |-- feature_route_popularity_score: string (nullable = true)
//  |-- feature_carrier_size_category: string (nullable = true)
//  |-- label_arr_delay_filled: double (nullable = true)
//  |-- label_nas_delay_filled: double (nullable = true)
//  |-- label_weather_delay_filled: double (nullable = true)
//  |-- label_weather_delay_was_missing: integer (nullable = true)
//  |-- label_nas_delay_was_missing: integer (nullable = true)
//  |-- label_arr_delay_was_missing: integer (nullable = true)
//  |-- label_is_early: integer (nullable = true)
//  |-- label_total_weather_nas_delay: double (nullable = true)
//  |-- label_is_delayed_15min: integer (nullable = true)
//  |-- label_has_nas_delay: integer (nullable = true)
//  |-- label_is_delayed_30min: integer (nullable = true)
//  |-- label_is_delayed_60min: integer (nullable = true)
//  |-- label_is_delayed_45min: integer (nullable = true)
//  |-- label_is_delayed_90min: integer (nullable = true)
//  |-- label_has_weather_delay: integer (nullable = true)
//  |-- label_is_on_time: integer (nullable = true)
//  |-- label_has_any_weather_nas_delay: integer (nullable = true)
//  |-- origin_weather_StationType_array: array (nullable = true)
//  |    |-- element: integer (containsNull = false)
//  |-- origin_weather_SkyCondition_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_SkyConditionFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_Visibility_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_VisibilityFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_WeatherType_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_WeatherTypeFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_DryBulbFarenheit_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_DryBulbFarenheitFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_DryBulbCelsius_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_DryBulbCelsiusFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_WetBulbFarenheit_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_WetBulbFarenheitFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_WetBulbCelsius_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_WetBulbCelsiusFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_DewPointFarenheit_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_DewPointFarenheitFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_DewPointCelsius_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_DewPointCelsiusFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_RelativeHumidity_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_RelativeHumidityFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_WindSpeed_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_WindSpeedFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_WindDirection_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_WindDirectionFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_ValueForWindCharacter_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_ValueForWindCharacterFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_StationPressure_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_StationPressureFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_PressureTendency_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_PressureTendencyFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_PressureChange_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_PressureChangeFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_SeaLevelPressure_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_SeaLevelPressureFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_RecordType_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_RecordTypeFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_HourlyPrecip_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_HourlyPrecipFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_Altimeter_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_AltimeterFlag_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_most_critical_sky_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_lowest_cloud_height_array: array (nullable = true)
//  |    |-- element: integer (containsNull = false)
//  |-- origin_weather_ceiling_array: array (nullable = true)
//  |    |-- element: integer (containsNull = false)
//  |-- origin_weather_num_cloud_layers_array: array (nullable = true)
//  |    |-- element: integer (containsNull = false)
//  |-- origin_weather_cloud_risk_score_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_has_overcast_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_has_broken_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_has_obscured_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_is_clear_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_has_low_ceiling_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_visibility_miles_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_visibility_km_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_visibility_category_array: array (nullable = true)
//  |    |-- element: string (containsNull = false)
//  |-- origin_weather_visibility_risk_score_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_is_low_visibility_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_is_very_low_visibility_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_visibility_normalized_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_visibility_inverse_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_weather_severity_index_array: array (nullable = true)
//  |    |-- element: double (containsNull = false)
//  |-- origin_weather_is_vfr_conditions_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_is_ifr_conditions_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_requires_cat_ii_array: array (nullable = true)
//  |    |-- element: boolean (containsNull = false)
//  |-- origin_weather_operations_risk_level_array: array (nullable = true)
//  |    |-- element: integer (containsNull = false)
//  |-- origin_weather_obs_count: integer (nullable = true)
//  |-- dest_weather_StationType_array: array (nullable = false)
//  |    |-- element: integer (containsNull = false)
//  |-- dest_weather_SkyCondition_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_SkyConditionFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_Visibility_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_VisibilityFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_WeatherType_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_WeatherTypeFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_DryBulbFarenheit_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_DryBulbFarenheitFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_DryBulbCelsius_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_DryBulbCelsiusFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_WetBulbFarenheit_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_WetBulbFarenheitFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_WetBulbCelsius_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_WetBulbCelsiusFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_DewPointFarenheit_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_DewPointFarenheitFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_DewPointCelsius_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_DewPointCelsiusFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_RelativeHumidity_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_RelativeHumidityFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_WindSpeed_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_WindSpeedFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_WindDirection_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_WindDirectionFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_ValueForWindCharacter_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_ValueForWindCharacterFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_StationPressure_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_StationPressureFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_PressureTendency_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_PressureTendencyFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_PressureChange_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_PressureChangeFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_SeaLevelPressure_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_SeaLevelPressureFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_RecordType_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_RecordTypeFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_HourlyPrecip_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_HourlyPrecipFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_Altimeter_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_AltimeterFlag_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_most_critical_sky_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_lowest_cloud_height_array: array (nullable = false)
//  |    |-- element: integer (containsNull = false)
//  |-- dest_weather_ceiling_array: array (nullable = false)
//  |    |-- element: integer (containsNull = false)
//  |-- dest_weather_num_cloud_layers_array: array (nullable = false)
//  |    |-- element: integer (containsNull = false)
//  |-- dest_weather_cloud_risk_score_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_has_overcast_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_has_broken_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_has_obscured_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_is_clear_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_has_low_ceiling_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_visibility_miles_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_visibility_km_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_visibility_category_array: array (nullable = false)
//  |    |-- element: string (containsNull = false)
//  |-- dest_weather_visibility_risk_score_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_is_low_visibility_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_is_very_low_visibility_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_visibility_normalized_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_visibility_inverse_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_weather_severity_index_array: array (nullable = false)
//  |    |-- element: double (containsNull = false)
//  |-- dest_weather_is_vfr_conditions_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_is_ifr_conditions_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_requires_cat_ii_array: array (nullable = false)
//  |    |-- element: boolean (containsNull = false)
//  |-- dest_weather_operations_risk_level_array: array (nullable = false)
//  |    |-- element: integer (containsNull = false)
//  |-- dest_weather_obs_count: integer (nullable = false)

// %%
val addedFeatureColumns = Seq(
  "FL_DATE",
  "UTC_FL_DATE",
  /**"OP_CARRIER_AIRLINE_ID",
  "OP_CARRIER_FL_NUM",
  "ORIGIN_AIRPORT_ID",
  "DEST_AIRPORT_ID",
  "WEATHER_DELAY",
  "NAS_DELAY",**/

  "CRS_DEP_TIME",
  "UTC_CRS_DEP_TIME",  
  "CRS_ELAPSED_TIME",
    
  //"ORIGIN_WBAN",
  "ORIGIN_TIMEZONE",  
  //"DEST_WBAN",  
  //"DEST_TIMEZONE",  
    
  /**"feature_flight_timestamp",
  "feature_flight_year",
  "feature_flight_month",
  "feature_flight_quarter",
  "feature_flight_day_of_month",
  "feature_flight_day_of_week",
  "feature_flight_day_of_year",
  "feature_flight_week_of_year",
  "feature_departure_hour",
  "feature_departure_minute",
  "feature_departure_hour_decimal",
  "feature_departure_quarter_day",
  "feature_minutes_since_midnight",
  "feature_departure_quarter_name",
  "feature_departure_time_period",**/

  "feature_departure_hour_rounded",
  "feature_utc_departure_hour_rounded",  
  //"feature_departure_minutes_total",
      //"feature_arrival_hour_rounded", 
  /**"feature_arrival_minutes_total",
  "feature_arrival_time",
  "feature_arrival_hour",
  "feature_arrival_minute",
  "feature_arrival_hour_decimal",**/
      //"feature_crosses_midnight",
      //"feature_flight_days_span", "feature_arrival_date"  
   "origin_weather_SkyCondition_array",
   "origin_weather_SkyConditionFlag_array" 
)

val df = dataPipelineDF
  .select(addedFeatureColumns.head, addedFeatureColumns.tail: _*)
df.show(100)
// Out:
// +----------+-----------+------------+----------------+----------------+---------------+------------------------------+----------------------------------+---------------------------------+-------------------------------------+
// |   FL_DATE|UTC_FL_DATE|CRS_DEP_TIME|UTC_CRS_DEP_TIME|CRS_ELAPSED_TIME|ORIGIN_TIMEZONE|feature_departure_hour_rounded|feature_utc_departure_hour_rounded|origin_weather_SkyCondition_array|origin_weather_SkyConditionFlag_array|
// +----------+-----------+------------+----------------+----------------+---------------+------------------------------+----------------------------------+---------------------------------+-------------------------------------+
// |2012-01-27| 2012-01-27|        1047|            1847|            82.0|             -8|                          1100|                              1900|                               []|                                   []|
// |2012-01-20| 2012-01-20|         700|            1500|            96.0|             -8|                           700|                              1500|                               []|                                   []|
// |2012-01-13| 2012-01-13|        1038|            1838|           247.0|             -8|                          1100|                              1900|                               []|                                   []|
// |2012-01-11| 2012-01-11|        1430|            2030|           152.0|             -6|                          1500|                              2100|                               []|                                   []|
// |2012-01-21| 2012-01-22|        1415|            0015|           341.0|            -10|                          1400|                                 0|                               []|                                   []|
// |2012-01-26| 2012-01-26|        1610|            2210|            80.0|             -6|                          1600|                              2200|                               []|                                   []|
// |2012-01-30| 2012-01-30|        1532|            2032|           110.0|             -5|                          1600|                              2100|                               []|                                   []|
// |2012-01-21| 2012-01-21|        1630|            2130|           210.0|             -5|                          1700|                              2200|                               []|                                   []|
// |2012-01-30| 2012-01-31|        1950|            0250|           182.0|             -7|                          2000|                               300|                               []|                                   []|
// |2012-01-03| 2012-01-03|         740|            1440|           105.0|             -7|                           800|                              1500|                               []|                                   []|
// |2012-01-03| 2012-01-03|        1730|            2230|           160.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-05| 2012-01-05|        1455|            1955|           119.0|             -5|                          1500|                              2000|                               []|                                   []|
// |2012-01-10| 2012-01-10|        1155|            1655|           245.0|             -5|                          1200|                              1700|                               []|                                   []|
// |2012-01-19| 2012-01-19|        1700|            2200|           377.0|             -5|                          1700|                              2200|                               []|                                   []|
// |2012-01-10| 2012-01-10|        1845|            2245|           235.0|             -4|                          1900|                              2300|                               []|                                   []|
// |2012-01-19| 2012-01-20|        1900|            0100|           139.0|             -6|                          1900|                               100|                               []|                                   []|
// |2012-01-19| 2012-01-20|        2115|            0315|           270.0|             -6|                          2100|                               300|                               []|                                   []|
// |2012-01-05| 2012-01-05|        1645|            2245|           105.0|             -6|                          1700|                              2300|                               []|                                   []|
// |2012-01-11| 2012-01-11|        1300|            1900|            93.0|             -6|                          1300|                              1900|                               []|                                   []|
// |2012-01-29| 2012-01-29|         740|            1240|           231.0|             -5|                           800|                              1300|                               []|                                   []|
// |2012-01-17| 2012-01-17|        1530|            2130|            70.0|             -6|                          1600|                              2200|                               []|                                   []|
// |2012-01-30| 2012-01-30|        1430|            1930|           169.0|             -5|                          1500|                              2000|                               []|                                   []|
// |2012-01-02| 2012-01-02|        1430|            1930|            88.0|             -5|                          1500|                              2000|                               []|                                   []|
// |2012-01-12| 2012-01-13|        1635|            0035|            65.0|             -8|                          1700|                               100|                               []|                                   []|
// |2012-01-19| 2012-01-19|         910|            1410|           395.0|             -5|                           900|                              1400|                               []|                                   []|
// |2012-01-15| 2012-01-15|        1608|            2108|           184.0|             -5|                          1600|                              2100|                               []|                                   []|
// |2012-01-20| 2012-01-20|        1350|            2150|           100.0|             -8|                          1400|                              2200|                               []|                                   []|
// |2012-01-30| 2012-01-30|        1546|            2046|           118.0|             -5|                          1600|                              2100|                               []|                                   []|
// |2012-01-26| 2012-01-26|        1250|            2050|            90.0|             -8|                          1300|                              2100|                               []|                                   []|
// |2012-01-25| 2012-01-25|        1103|            1803|           135.0|             -7|                          1100|                              1800|                               []|                                   []|
// |2012-01-09| 2012-01-09|        1220|            1720|            70.0|             -5|                          1200|                              1700|                               []|                                   []|
// |2012-01-09| 2012-01-10|        2025|            0225|           100.0|             -6|                          2000|                               200|                               []|                                   []|
// |2012-01-17| 2012-01-17|        1810|            2310|           323.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-21| 2012-01-21|        1443|            2243|            39.0|             -8|                          1500|                              2300|                               []|                                   []|
// |2012-01-24| 2012-01-24|         840|            1540|           100.0|             -7|                           900|                              1600|                               []|                                   []|
// |2012-01-09| 2012-01-09|        1321|            1821|            68.0|             -5|                          1300|                              1800|                               []|                                   []|
// |2012-01-25| 2012-01-26|        1640|            0040|           290.0|             -8|                          1700|                               100|                               []|                                   []|
// |2012-01-25| 2012-01-25|         810|            1610|           107.0|             -8|                           800|                              1600|                               []|                                   []|
// |2012-01-22| 2012-01-22|        1030|            1530|            73.0|             -5|                          1100|                              1600|                               []|                                   []|
// |2012-01-23| 2012-01-23|        1105|            1605|           219.0|             -5|                          1100|                              1600|                               []|                                   []|
// |2012-01-20| 2012-01-21|        1950|            0150|           209.0|             -6|                          2000|                               200|                               []|                                   []|
// |2012-01-18| 2012-01-18|        1355|            1955|           264.0|             -6|                          1400|                              2000|                               []|                                   []|
// |2012-01-25| 2012-01-25|        1310|            1810|           276.0|             -5|                          1300|                              1800|                               []|                                   []|
// |2012-01-27| 2012-01-27|        1757|            2257|           241.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-31| 2012-01-31|        1625|            2125|           110.0|             -5|                          1600|                              2100|                               []|                                   []|
// |2012-01-22| 2012-01-23|        2115|            0415|            86.0|             -7|                          2100|                               400|                               []|                                   []|
// |2012-01-15| 2012-01-15|        1315|            2115|           120.0|             -8|                          1300|                              2100|                               []|                                   []|
// |2012-01-17| 2012-01-17|        1700|            2200|            70.0|             -5|                          1700|                              2200|                               []|                                   []|
// |2012-01-13| 2012-01-14|        1635|            0035|           180.0|             -8|                          1700|                               100|                               []|                                   []|
// |2012-01-24| 2012-01-24|        1745|            2245|           192.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-23| 2012-01-23|        1559|            2059|           112.0|             -5|                          1600|                              2100|                               []|                                   []|
// |2012-01-20| 2012-01-20|        1340|            2140|           150.0|             -8|                          1400|                              2200|                               []|                                   []|
// |2012-01-26| 2012-01-26|         545|            1345|           148.0|             -8|                           600|                              1400|                               []|                                   []|
// |2012-01-12| 2012-01-12|        1145|            1745|            75.0|             -6|                          1200|                              1800|                               []|                                   []|
// |2012-01-11| 2012-01-12|        1810|            0010|            48.0|             -6|                          1800|                                 0|                               []|                                   []|
// |2012-01-12| 2012-01-13|        2105|            0305|            95.0|             -6|                          2100|                               300|                               []|                                   []|
// |2012-01-12| 2012-01-13|        2116|            0316|            75.0|             -6|                          2100|                               300|                               []|                                   []|
// |2012-01-21| 2012-01-22|        1805|            0005|            88.0|             -6|                          1800|                                 0|                               []|                                   []|
// |2012-01-02| 2012-01-02|        1430|            2330|           200.0|             -9|                          1500|                                 0|                               []|                                   []|
// |2012-01-10| 2012-01-10|        1337|            2037|           162.0|             -7|                          1400|                              2100|                               []|                                   []|
// |2012-01-12| 2012-01-12|        1755|            2255|            88.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-16| 2012-01-16|         700|            1200|           159.0|             -5|                           700|                              1200|                               []|                                   []|
// |2012-01-07| 2012-01-07|        1435|            2235|            90.0|             -8|                          1500|                              2300|                               []|                                   []|
// |2012-01-18| 2012-01-18|        1742|            2342|           213.0|             -6|                          1800|                                 0|                               []|                                   []|
// |2012-01-01| 2012-01-02|        1820|            0020|           105.0|             -6|                          1800|                                 0|                               []|                                   []|
// |2012-01-02| 2012-01-03|        2005|            0205|           110.0|             -6|                          2000|                               200|                               []|                                   []|
// |2012-01-06| 2012-01-07|        1407|            0007|           323.0|            -10|                          1400|                                 0|                               []|                                   []|
// |2012-01-01| 2012-01-02|        2236|            0636|            99.0|             -8|                          2300|                               700|                               []|                                   []|
// |2012-01-04| 2012-01-04|        1045|            1845|           107.0|             -8|                          1100|                              1900|                               []|                                   []|
// |2012-01-15| 2012-01-15|        1415|            2115|           100.0|             -7|                          1400|                              2100|                               []|                                   []|
// |2012-01-10| 2012-01-10|         905|            1505|            55.0|             -6|                           900|                              1500|                               []|                                   []|
// |2012-01-27| 2012-01-27|        1411|            2011|           109.0|             -6|                          1400|                              2000|                               []|                                   []|
// |2012-01-27| 2012-01-27|         845|            1645|            70.0|             -8|                           900|                              1700|                               []|                                   []|
// |2012-01-11| 2012-01-12|        1855|            0055|            70.0|             -6|                          1900|                               100|                               []|                                   []|
// |2012-01-01| 2012-01-01|         705|            1305|           248.0|             -6|                           700|                              1300|                               []|                                   []|
// |2012-01-28| 2012-01-28|        1705|            2205|            58.0|             -5|                          1700|                              2200|                               []|                                   []|
// |2012-01-04| 2012-01-04|         815|            1415|           124.0|             -6|                           800|                              1400|                               []|                                   []|
// |2012-01-17| 2012-01-18|        2110|            0310|           110.0|             -6|                          2100|                               300|                               []|                                   []|
// |2012-01-29| 2012-01-29|        1513|            2113|            91.0|             -6|                          1500|                              2100|                               []|                                   []|
// |2012-01-17| 2012-01-17|         605|            1205|           161.0|             -6|                           600|                              1200|                               []|                                   []|
// |2012-01-29| 2012-01-29|        1705|            2205|            61.0|             -5|                          1700|                              2200|                               []|                                   []|
// |2012-01-03| 2012-01-04|        1950|            0050|           194.0|             -5|                          2000|                               100|                               []|                                   []|
// |2012-01-09| 2012-01-09|         550|            1150|           168.0|             -6|                           600|                              1200|                               []|                                   []|
// |2012-01-27| 2012-01-27|         715|            1315|            87.0|             -6|                           700|                              1300|                               []|                                   []|
// |2012-01-29| 2012-01-30|        1850|            0050|           196.0|             -6|                          1900|                               100|                               []|                                   []|
// |2012-01-12| 2012-01-12|        1800|            2300|           166.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-06| 2012-01-06|        1121|            1721|           108.0|             -6|                          1100|                              1700|                               []|                                   []|
// |2012-01-27| 2012-01-27|        1437|            2337|           105.0|             -9|                          1500|                                 0|                               []|                                   []|
// |2012-01-22| 2012-01-22|        1745|            2345|           130.0|             -6|                          1800|                                 0|                               []|                                   []|
// |2012-01-12| 2012-01-12|         720|            1420|           109.0|             -7|                           700|                              1400|                               []|                                   []|
// |2012-01-18| 2012-01-18|        1540|            2040|            84.0|             -5|                          1600|                              2100|                               []|                                   []|
// |2012-01-04| 2012-01-04|        1245|            1745|           123.0|             -5|                          1300|                              1800|                               []|                                   []|
// |2012-01-12| 2012-01-13|        1940|            0040|            70.0|             -5|                          2000|                               100|                               []|                                   []|
// |2012-01-10| 2012-01-10|        1750|            2250|           250.0|             -5|                          1800|                              2300|                               []|                                   []|
// |2012-01-30| 2012-01-30|        1235|            1735|           150.0|             -5|                          1300|                              1800|                               []|                                   []|
// |2012-01-15| 2012-01-16|        1955|            0255|            84.0|             -7|                          2000|                               300|                               []|                                   []|
// |2012-01-09| 2012-01-09|         828|            1528|           231.0|             -7|                           800|                              1500|                               []|                                   []|
// |2012-01-05| 2012-01-05|        1247|            1947|           144.0|             -7|                          1300|                              2000|                               []|                                   []|
// |2012-01-25| 2012-01-25|        1115|            1715|           190.0|             -6|                          1100|                              1700|                               []|                                   []|
// |2012-01-04| 2012-01-04|        1536|            2136|            68.0|             -6|                          1600|                              2200|                               []|                                   []|
// +----------+-----------+------------+----------------+----------------+---------------+------------------------------+----------------------------------+---------------------------------+-------------------------------------+
// only showing top 100 rows
// addedFeatureColumns = List(FL_DATE, UTC_FL_DATE, CRS_DEP_TIME, UTC_CRS_DEP_TIME, CRS_ELAPSED_TIME, ORIGIN_TIMEZONE, feature_departure_hour_rounded, feature_utc_departure_hour_rounded, origin_weather_SkyCondition_array, origin_weather_SkyConditionFlag_array)
// df = [FL_DATE: date, UTC_FL_DATE: date ... 8 more fields]
// [FL_DATE: date, UTC_FL_DATE: date ... 8 more fields]
