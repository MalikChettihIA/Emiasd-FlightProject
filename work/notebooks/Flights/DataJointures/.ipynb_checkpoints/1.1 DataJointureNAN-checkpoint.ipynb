// %% [markdown]
// # Jointure NAN Values

// %%
%AddJar file:///home/jovyan/work/apps/Emiasd-Flight-Data-Analysis.jar
// Out:
// Starting download from file:///home/jovyan/work/apps/Emiasd-Flight-Data-Analysis.jar
// Finished download of Emiasd-Flight-Data-Analysis.jar
// Using cached version of Emiasd-Flight-Data-Analysis.jar

// %%
import org.apache.spark.sql.SparkSession
import com.flightdelay.config.{AppConfiguration, ConfigurationLoader, ExperimentConfig}
import com.flightdelay.data.loaders.FlightDataLoader

//Env Configuration
val args: Array[String] = Array("jupyter")

val spark = SparkSession.builder()
  .config(sc.getConf)
  .getOrCreate()

// Rendre la session Spark implicite
implicit val session = spark
implicit val configuration: AppConfiguration = ConfigurationLoader.loadConfiguration(args)
implicit val experiment: ExperimentConfig = configuration.experiments(0)
// Out:
// lastException = null
// args = Array(jupyter)
// spark = org.apache.spark.sql.SparkSession@3a307260
// session = org.apache.spark.sql.SparkSession@3a307260
// configuration = AppConfiguration(local,CommonConfig(42,DataConfig(/home/jovyan/work/data,FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Flights/201201*.csv),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Weather/20101*.txt),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/wban_airport_timezone.csv)),OutputConfig(/home/jovyan/work/output,FileConfig(/home/jovyan/work/output...
// AppConfiguration(local,CommonConfig(42,DataConfig(/home/jovyan/work/data,FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Flights/201201*.csv),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/Weather/20101*.txt),FileConfig(/home/jovyan/work/data/FLIGHT-3Y/wban_airport_timezone.csv)),OutputConfig(/home/jovyan/work/output,FileConfig(/home/jovyan/work/output...

// %%
val joinedDFPath = s"${configuration.common.output.basePath}/Experience-20-D2_60-weatherDepthHours_3_0/data/joined_flights_weather.parquet"
val joinedDF = spark.read.parquet(joinedDFPath)

joinedDF.show(1, 1000, true)
// Out:
// -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//  CRS_DEP_TIME                       | 700
//  CRS_ELAPSED_TIME                   | 103.0
//  DEST_AIRPORT_ID                    | 10397
//  DEST_WBAN                          | 13874
//  OP_CARRIER_AIRLINE_ID              | 19790
//  ORIGIN_AIRPORT_ID                  | 13360
//  ORIGIN_WBAN                        | 12838
//  PREV_AIRCRAFT_ARR_DELAY            | 0.0
//  UTC_FL_DATE                        | 2012-01-26
//  feature_arrival_time_period        | Late_Morning
//  feature_avg_delay                  | 0.0
//  feature_departure_hour_rounded     | 700
//  feature_departure_time_period      | Morning
//  feature_flight_week_of_year        | 4
//  feature_turnaround_buffer          | 0.0
//  feature_utc_departure_hour_rounded | 1200
//  is_delayed                         | 0
//  origin_weather_observations        | [{140.0, 33.0, perturbe, 0, 66.0, 0, 21.0, IFR, 77.0, 0, 3.0, 0, 1.0, 0, 69.0, IFR, moderate, 1, 0, 1, 2, 30.03, 25.0, 3.0, 0, 0,  , 20.0, 0, 2, 30.03, 0, 2300, 1, 0, 30.0, 0, NULL, 0, 1, 2300, 26, 0, 1.609, 0, 1.0, 18.9, BKN, 33.0, 0.1, 0, 3.0, 0, 0, 0, 8, 0, 0, 99.0, 0, 70.0, 0, 3}, {110.0, NULL, unknown, 0, 64.0, 0, 20.3, IFR, 77.0, 0, 2.5999999999999996, 0, 1.0, 0, 64.0, IFR, moderate, 0, 0, 1, 2, 30.11, 25.0, 3.0, 0, 0,  , 17.0, 0, 2, NULL, 0, 2800, 1, 0, 30.08, 0, NULL, 0, 2, 99999, 23, 0, 1.609, 0, 1.0, 18.0, SCT, NULL, 0.1, 0, 2.0, 0, 0, 0, NULL, 0, 0, NULL, 0, 69.0, 0, 2}, {150.0, NULL, unknown, 0, 64.0, 0, 20.3, IFR, 77.0, 0, 3.0, 0, 1.0, 0, 64.0, IFR, moderate, 1, 0, 1, 2, 30.13, 25.0, 3.0, 0, 0,  , 14.0, 0, 2, NULL, 0, 2500, 1, 0, 30.1, 0, NULL, 0, 1, 2500, NULL, 0, 1.609, 0, 1.0, 18.0, BKN, NULL, 0.1, 0, 3.0, 0, 0, 0, NULL, 0, 0, NULL, 0, 69.0, 0, 1}, {140.0, 4.0, stable, 0, 64.0, 0, 20.2, IFR, 76.0, 0, 2.5999999999999996, 0, 1.0, 0, 67.0, IFR, moderate, 0, 0, 1, 2, 30....
// only showing top 1 row
// joinedDFPath = /home/jovyan/work/output/Experience-20-D2_60-weatherDepthHours_3_0/data/joined_flights_weather.parquet
// joinedDF = [CRS_DEP_TIME: int, CRS_ELAPSED_TIME: double ... 16 more fields]
// [CRS_DEP_TIME: int, CRS_ELAPSED_TIME: double ... 16 more fields]

// %%
val joinedExplodedDFPath = s"${configuration.common.output.basePath}/Experience-20-D2_60-weatherDepthHours_3_0/data/joined_exploded_data.parquet"
val joinedExplodedDF = spark.read.parquet(joinedExplodedDFPath)

joinedExplodedDF.show(1, 1000, true)
// Out:
// -RECORD 0----------------------------------------------------------------
//  CRS_DEP_TIME                                       | 700
//  CRS_ELAPSED_TIME                                   | 103.0
//  DEST_AIRPORT_ID                                    | 10397
//  DEST_WBAN                                          | 13874
//  OP_CARRIER_AIRLINE_ID                              | 19790
//  ORIGIN_AIRPORT_ID                                  | 13360
//  ORIGIN_WBAN                                        | 12838
//  PREV_AIRCRAFT_ARR_DELAY                            | 0.0
//  UTC_FL_DATE                                        | 2012-01-26
//  feature_arrival_time_period                        | Late_Morning
//  feature_avg_delay                                  | 0.0
//  feature_departure_hour_rounded                     | 700
//  feature_departure_time_period                      | Morning
//  feature_flight_week_of_year                        | 4
//  feature_turnaround_buffer                          | 0.0
//  feature_utc_departure_hour_rounded                 | 1200
//  is_delayed                                         | 0
//  origin_weather_WindDirection-3                     | 140.0
//  origin_weather_PressureChange-3                    | 33.0
//  origin_weather_feature_pressure_bucket-3           | perturbe
//  origin_weather_has_hail-3                          | 0
//  origin_weather_DewPointFarenheit-3                 | 66.0
//  origin_weather_has_visible_moisture-3              | 0
//  origin_weather_WetBulbCelsius-3                    | 21.0
//  origin_weather_feature_flight_category-3           | IFR
//  origin_weather_DryBulbFarenheit-3                  | 77.0
//  origin_weather_weather_hazard_level-3              | 0
//  origin_weather_feature_weather_severity_index-3    | 3.0
//  origin_weather_has_obscuration-3                   | 0
//  origin_weather_feature_visibility_miles-3          | 1.0
//  origin_weather_has_precipitation-3                 | 0
//  origin_weather_RelativeHumidity-3                  | 69.0
//  origin_weather_feature_visibility_category-3       | IFR
//  origin_weather_weather_intensity-3                 | moderate
//  origin_weather_feature_has_broken-3                | 1
//  origin_weather_has_thunderstorm-3                  | 0
//  origin_weather_feature_is_ifr_conditions-3         | 1
//  origin_weather_feature_flight_category_ordinal-3   | 2
//  origin_weather_Altimeter-3                         | 30.03
//  origin_weather_DryBulbCelsius-3                    | 25.0
//  origin_weather_feature_visibility_risk_score-3     | 3.0
//  origin_weather_has_freezing_precip-3               | 0
//  origin_weather_feature_requires_cat_ii-3           | 0
//  origin_weather_extracted_codes-3                   |
//  origin_weather_WindSpeed-3                         | 20.0
//  origin_weather_has_rain-3                          | 0
//  origin_weather_feature_operations_risk_level-3     | 2
//  origin_weather_SeaLevelPressure-3                  | 30.03
//  origin_weather_Icing_Risk_Flag-3                   | 0
//  origin_weather_feature_lowest_cloud_height-3       | 2300
//  origin_weather_feature_is_low_visibility-3         | 1
//  origin_weather_has_snow-3                          | 0
//  origin_weather_StationPressure-3                   | 30.0
//  origin_weather_Icing_Risk_Level-3                  | 0
//  origin_weather_HourlyPrecip-3                      | NULL
//  origin_weather_feature_is_clear-3                  | 0
//  origin_weather_feature_num_cloud_layers-3          | 1
//  origin_weather_feature_ceiling-3                   | 2300
//  origin_weather_ValueForWindCharacter-3             | 26
//  origin_weather_feature_has_low_ceiling-3           | 0
//  origin_weather_feature_visibility_km-3             | 1.609
//  origin_weather_feature_precipitation_intensity-3   | 0
//  origin_weather_feature_visibility_inverse-3        | 1.0
//  origin_weather_DewPointCelsius-3                   | 18.9
//  origin_weather_feature_most_critical_sky-3         | BKN
//  origin_weather_press_change_abs-3                  | 33.0
//  origin_weather_feature_visibility_normalized-3     | 0.1
//  origin_weather_feature_has_overcast-3              | 0
//  origin_weather_feature_cloud_risk_score-3          | 3.0
//  origin_weather_feature_has_obscured-3              | 0
//  origin_weather_intensity_light-3                   | 0
//  origin_weather_has_freezing-3                      | 0
//  origin_weather_PressureTendency-3                  | 8
//  origin_weather_intensity_heavy-3                   | 0
//  origin_weather_feature_is_very_low_visibility-3    | 0
//  origin_weather_feature_pressure_visibility_combo-3 | 99.0
//  origin_weather_has_hazardous-3                     | 0
//  origin_weather_WetBulbFarenheit-3                  | 70.0
//  origin_weather_feature_is_vfr_conditions-3         | 0
//  origin_weather_WindDirection-2                     | 110.0
//  origin_weather_PressureChange-2                    | NULL
//  origin_weather_feature_pressure_bucket-2           | unknown
//  origin_weather_has_hail-2                          | 0
//  origin_weather_DewPointFarenheit-2                 | 64.0
//  origin_weather_has_visible_moisture-2              | 0
//  origin_weather_WetBulbCelsius-2                    | 20.3
//  origin_weather_feature_flight_category-2           | IFR
//  origin_weather_DryBulbFarenheit-2                  | 77.0
//  origin_weather_weather_hazard_level-2              | 0
//  origin_weather_feature_weather_severity_index-2    | 2.5999999999999996
//  origin_weather_has_obscuration-2                   | 0
//  origin_weather_feature_visibility_miles-2          | 1.0
//  origin_weather_has_precipitation-2                 | 0
//  origin_weather_RelativeHumidity-2                  | 64.0
//  origin_weather_feature_visibility_category-2       | IFR
//  origin_weather_weather_intensity-2                 | moderate
//  origin_weather_feature_has_broken-2                | 0
//  origin_weather_has_thunderstorm-2                  | 0
//  origin_weather_feature_is_ifr_conditions-2         | 1
//  origin_weather_feature_flight_category_ordinal-2   | 2
//  origin_weather_Altimeter-2                         | 30.11
//  origin_weather_DryBulbCelsius-2                    | 25.0
//  origin_weather_feature_visibility_risk_score-2     | 3.0
//  origin_weather_has_freezing_precip-2               | 0
//  origin_weather_feature_requires_cat_ii-2           | 0
//  origin_weather_extracted_codes-2                   |
//  origin_weather_WindSpeed-2                         | 17.0
//  origin_weather_has_rain-2                          | 0
//  origin_weather_feature_operations_risk_level-2     | 2
//  origin_weather_SeaLevelPressure-2                  | NULL
//  origin_weather_Icing_Risk_Flag-2                   | 0
//  origin_weather_feature_lowest_cloud_height-2       | 2800
//  origin_weather_feature_is_low_visibility-2         | 1
//  origin_weather_has_snow-2                          | 0
//  origin_weather_StationPressure-2                   | 30.08
//  origin_weather_Icing_Risk_Level-2                  | 0
//  origin_weather_HourlyPrecip-2                      | NULL
//  origin_weather_feature_is_clear-2                  | 0
//  origin_weather_feature_num_cloud_layers-2          | 2
//  origin_weather_feature_ceiling-2                   | 99999
//  origin_weather_ValueForWindCharacter-2             | 23
//  origin_weather_feature_has_low_ceiling-2           | 0
//  origin_weather_feature_visibility_km-2             | 1.609
//  origin_weather_feature_precipitation_intensity-2   | 0
//  origin_weather_feature_visibility_inverse-2        | 1.0
//  origin_weather_DewPointCelsius-2                   | 18.0
//  origin_weather_feature_most_critical_sky-2         | SCT
//  origin_weather_press_change_abs-2                  | NULL
//  origin_weather_feature_visibility_normalized-2     | 0.1
//  origin_weather_feature_has_overcast-2              | 0
//  origin_weather_feature_cloud_risk_score-2          | 2.0
//  origin_weather_feature_has_obscured-2              | 0
//  origin_weather_intensity_light-2                   | 0
//  origin_weather_has_freezing-2                      | 0
//  origin_weather_PressureTendency-2                  | NULL
//  origin_weather_intensity_heavy-2                   | 0
//  origin_weather_feature_is_very_low_visibility-2    | 0
//  origin_weather_feature_pressure_visibility_combo-2 | NULL
//  origin_weather_has_hazardous-2                     | 0
//  origin_weather_WetBulbFarenheit-2                  | 69.0
//  origin_weather_feature_is_vfr_conditions-2         | 0
//  origin_weather_WindDirection-1                     | 150.0
//  origin_weather_PressureChange-1                    | NULL
//  origin_weather_feature_pressure_bucket-1           | unknown
//  origin_weather_has_hail-1                          | 0
//  origin_weather_DewPointFarenheit-1                 | 64.0
//  origin_weather_has_visible_moisture-1              | 0
//  origin_weather_WetBulbCelsius-1                    | 20.3
//  origin_weather_feature_flight_category-1           | IFR
//  origin_weather_DryBulbFarenheit-1                  | 77.0
//  origin_weather_weather_hazard_level-1              | 0
//  origin_weather_feature_weather_severity_index-1    | 3.0
//  origin_weather_has_obscuration-1                   | 0
//  origin_weather_feature_visibility_miles-1          | 1.0
//  origin_weather_has_precipitation-1                 | 0
//  origin_weather_RelativeHumidity-1                  | 64.0
//  origin_weather_feature_visibility_category-1       | IFR
//  origin_weather_weather_intensity-1                 | moderate
//  origin_weather_feature_has_broken-1                | 1
//  origin_weather_has_thunderstorm-1                  | 0
//  origin_weather_feature_is_ifr_conditions-1         | 1
//  origin_weather_feature_flight_category_ordinal-1   | 2
//  origin_weather_Altimeter-1                         | 30.13
//  origin_weather_DryBulbCelsius-1                    | 25.0
//  origin_weather_feature_visibility_risk_score-1     | 3.0
//  origin_weather_has_freezing_precip-1               | 0
//  origin_weather_feature_requires_cat_ii-1           | 0
//  origin_weather_extracted_codes-1                   |
//  origin_weather_WindSpeed-1                         | 14.0
//  origin_weather_has_rain-1                          | 0
//  origin_weather_feature_operations_risk_level-1     | 2
//  origin_weather_SeaLevelPressure-1                  | NULL
//  origin_weather_Icing_Risk_Flag-1                   | 0
//  origin_weather_feature_lowest_cloud_height-1       | 2500
//  origin_weather_feature_is_low_visibility-1         | 1
//  origin_weather_has_snow-1                          | 0
//  origin_weather_StationPressure-1                   | 30.1
//  origin_weather_Icing_Risk_Level-1                  | 0
//  origin_weather_HourlyPrecip-1                      | NULL
//  origin_weather_feature_is_clear-1                  | 0
//  origin_weather_feature_num_cloud_layers-1          | 1
//  origin_weather_feature_ceiling-1                   | 2500
//  origin_weather_ValueForWindCharacter-1             | NULL
//  origin_weather_feature_has_low_ceiling-1           | 0
//  origin_weather_feature_visibility_km-1             | 1.609
//  origin_weather_feature_precipitation_intensity-1   | 0
//  origin_weather_feature_visibility_inverse-1        | 1.0
//  origin_weather_DewPointCelsius-1                   | 18.0
//  origin_weather_feature_most_critical_sky-1         | BKN
//  origin_weather_press_change_abs-1                  | NULL
//  origin_weather_feature_visibility_normalized-1     | 0.1
//  origin_weather_feature_has_overcast-1              | 0
//  origin_weather_feature_cloud_risk_score-1          | 3.0
//  origin_weather_feature_has_obscured-1              | 0
//  origin_weather_intensity_light-1                   | 0
//  origin_weather_has_freezing-1                      | 0
//  origin_weather_PressureTendency-1                  | NULL
//  origin_weather_intensity_heavy-1                   | 0
//  origin_weather_feature_is_very_low_visibility-1    | 0
//  origin_weather_feature_pressure_visibility_combo-1 | NULL
//  origin_weather_has_hazardous-1                     | 0
//  origin_weather_WetBulbFarenheit-1                  | 69.0
//  origin_weather_feature_is_vfr_conditions-1         | 0
//  origin_weather_WindDirection-0                     | 140.0
//  origin_weather_PressureChange-0                    | 4.0
//  origin_weather_feature_pressure_bucket-0           | stable
//  origin_weather_has_hail-0                          | 0
//  origin_weather_DewPointFarenheit-0                 | 64.0
//  origin_weather_has_visible_moisture-0              | 0
//  origin_weather_WetBulbCelsius-0                    | 20.2
//  origin_weather_feature_flight_category-0           | IFR
//  origin_weather_DryBulbFarenheit-0                  | 76.0
//  origin_weather_weather_hazard_level-0              | 0
//  origin_weather_feature_weather_severity_index-0    | 2.5999999999999996
//  origin_weather_has_obscuration-0                   | 0
//  origin_weather_feature_visibility_miles-0          | 1.0
//  origin_weather_has_precipitation-0                 | 0
//  origin_weather_RelativeHumidity-0                  | 67.0
//  origin_weather_feature_visibility_category-0       | IFR
//  origin_weather_weather_intensity-0                 | moderate
//  origin_weather_feature_has_broken-0                | 0
//  origin_weather_has_thunderstorm-0                  | 0
//  origin_weather_feature_is_ifr_conditions-0         | 1
//  origin_weather_feature_flight_category_ordinal-0   | 2
//  origin_weather_Altimeter-0                         | 30.13
//  origin_weather_DryBulbCelsius-0                    | 24.4
//  origin_weather_feature_visibility_risk_score-0     | 3.0
//  origin_weather_has_freezing_precip-0               | 0
//  origin_weather_feature_requires_cat_ii-0           | 0
//  origin_weather_extracted_codes-0                   |
//  origin_weather_WindSpeed-0                         | 11.0
//  origin_weather_has_rain-0                          | 0
//  origin_weather_feature_operations_risk_level-0     | 2
//  origin_weather_SeaLevelPressure-0                  | 30.13
//  origin_weather_Icing_Risk_Flag-0                   | 0
//  origin_weather_feature_lowest_cloud_height-0       | 2300
//  origin_weather_feature_is_low_visibility-0         | 1
//  origin_weather_has_snow-0                          | 0
//  origin_weather_StationPressure-0                   | 30.1
//  origin_weather_Icing_Risk_Level-0                  | 0
//  origin_weather_HourlyPrecip-0                      | NULL
//  origin_weather_feature_is_clear-0                  | 0
//  origin_weather_feature_num_cloud_layers-0          | 1
//  origin_weather_feature_ceiling-0                   | 99999
//  origin_weather_ValueForWindCharacter-0             | 22
//  origin_weather_feature_has_low_ceiling-0           | 0
//  origin_weather_feature_visibility_km-0             | 1.609
//  origin_weather_feature_precipitation_intensity-0   | 0
//  origin_weather_feature_visibility_inverse-0        | 1.0
//  origin_weather_DewPointCelsius-0                   | 17.8
//  origin_weather_feature_most_critical_sky-0         | SCT
//  origin_weather_press_change_abs-0                  | 4.0
//  origin_weather_feature_visibility_normalized-0     | 0.1
//  origin_weather_feature_has_overcast-0              | 0
//  origin_weather_feature_cloud_risk_score-0          | 2.0
//  origin_weather_feature_has_obscured-0              | 0
//  origin_weather_intensity_light-0                   | 0
//  origin_weather_has_freezing-0                      | 0
//  origin_weather_PressureTendency-0                  | 3
//  origin_weather_intensity_heavy-0                   | 0
//  origin_weather_feature_is_very_low_visibility-0    | 0
//  origin_weather_feature_pressure_visibility_combo-0 | 12.0
//  origin_weather_has_hazardous-0                     | 0
//  origin_weather_WetBulbFarenheit-0                  | 68.0
//  origin_weather_feature_is_vfr_conditions-0         | 0
// only showing top 1 row
// joinedExplodedDFPath = /home/jovyan/work/output/Experience-20-D2_60-weatherDepthHours_3_0/data/joined_exploded_data.parquet
// joinedExplodedDF = [CRS_DEP_TIME: int, CRS_ELAPSED_TIME: double ... 263 more fields]
// [CRS_DEP_TIME: int, CRS_ELAPSED_TIME: double ... 263 more fields]

// %%
print(joinedExplodedDFPath)
// Out:
// /home/jovyan/work/output/Experience-20-D2_60-weatherDepthHours_3_0/data/joined_exploded_data.parquet

// %%
import org.apache.spark.sql.{DataFrame, Row, SparkSession}
import org.apache.spark.sql.functions._
import org.apache.spark.sql.types._

case class ColNullNaNStat(
  column: String,
  null_count: Long,
  nan_count: Long,
  total: Long,
  null_pct: Double,
  nan_pct: Double
)

def nullNanReport(df: DataFrame)(implicit spark: SparkSession): DataFrame = {
  val total = df.count()

  // Construire les agrégations NULL + NaN (NaN seulement pour Float/Double)
  val aggExprs = df.schema.fields.flatMap { f =>
    val c = col(f.name)
    val nullAgg = sum(when(c.isNull, 1).otherwise(0)).alias(s"${f.name}__nulls")
    val nanAgg =
      if (f.dataType == DoubleType || f.dataType == FloatType)
        Some(sum(when(isnan(c), 1).otherwise(0)).alias(s"${f.name}__nans"))
      else None
    nanAgg.toSeq :+ nullAgg
  }

  val countsRow = df.agg(aggExprs.head, aggExprs.tail: _*).first
  val countFieldNames = countsRow.schema.fieldNames.toSet

  import spark.implicits._
  val stats = df.schema.fields.map { f =>
    val name = f.name
    val nulls = countsRow.getAs[Long](s"${name}__nulls")
    val nans =
      if (countFieldNames.contains(s"${name}__nans"))
        countsRow.getAs[Long](s"${name}__nans")
      else 0L

    ColNullNaNStat(
      column     = name,
      null_count = nulls,
      nan_count  = nans,
      total      = total,
      null_pct   = if (total == 0) 0.0 else nulls * 100.0 / total,
      nan_pct    = if (total == 0) 0.0 else nans  * 100.0 / total
    )
  }.toSeq.toDS()

  stats.orderBy(desc("null_count"), desc("nan_count")).toDF()
}

val report = nullNanReport(joinedExplodedDF)
report.show(200, truncate = false)
// Out:
// defined class ColNullNaNStat
// report = [column: string, null_count: bigint ... 4 more fields]
// nullNanReport: (df: org.apache.spark.sql.DataFrame)(implicit spark: org.apache.spark.sql.SparkSession)org.apache.spark.sql.DataFrame
// +--------------------------------------------------+----------+---------+------+--------------------+-------+
// |column                                            |null_count|nan_count|total |null_pct            |nan_pct|
// +--------------------------------------------------+----------+---------+------+--------------------+-------+
// |origin_weather_HourlyPrecip-3                     |447072    |0        |473708|94.37712683762993   |0.0    |
// |origin_weather_HourlyPrecip-2                     |446052    |0        |473708|94.16180431827202   |0.0    |
// |origin_weather_HourlyPrecip-0                     |445166    |0        |473708|93.97476926714347   |0.0    |
// |origin_weather_HourlyPrecip-1                     |445051    |0        |473708|93.95049270858841   |0.0    |
// |origin_weather_ValueForWindCharacter-0            |403003    |0        |473708|85.07413849882207   |0.0    |
// |origin_weather_ValueForWindCharacter-2            |400367    |0        |473708|84.51767755663826   |0.0    |
// |origin_weather_ValueForWindCharacter-1            |400244    |0        |473708|84.4917121940098    |0.0    |
// |origin_weather_ValueForWindCharacter-3            |400212    |0        |473708|84.48495697771624   |0.0    |
// |origin_weather_feature_pressure_visibility_combo-3|339346    |0        |473708|71.63611338630548   |0.0    |
// |origin_weather_PressureChange-3                   |339346    |0        |473708|71.63611338630548   |0.0    |
// |origin_weather_press_change_abs-3                 |339346    |0        |473708|71.63611338630548   |0.0    |
// |origin_weather_PressureTendency-3                 |339346    |0        |473708|71.63611338630548   |0.0    |
// |origin_weather_press_change_abs-2                 |339339    |0        |473708|71.63463568274126   |0.0    |
// |origin_weather_PressureTendency-2                 |339339    |0        |473708|71.63463568274126   |0.0    |
// |origin_weather_PressureChange-2                   |339339    |0        |473708|71.63463568274126   |0.0    |
// |origin_weather_feature_pressure_visibility_combo-2|339339    |0        |473708|71.63463568274126   |0.0    |
// |origin_weather_PressureChange-0                   |334023    |0        |473708|70.51242537597001   |0.0    |
// |origin_weather_press_change_abs-0                 |334023    |0        |473708|70.51242537597001   |0.0    |
// |origin_weather_PressureTendency-0                 |334023    |0        |473708|70.51242537597001   |0.0    |
// |origin_weather_feature_pressure_visibility_combo-0|334023    |0        |473708|70.51242537597001   |0.0    |
// |origin_weather_press_change_abs-1                 |332908    |0        |473708|70.27704830824052   |0.0    |
// |origin_weather_PressureChange-1                   |332908    |0        |473708|70.27704830824052   |0.0    |
// |origin_weather_PressureTendency-1                 |332908    |0        |473708|70.27704830824052   |0.0    |
// |origin_weather_feature_pressure_visibility_combo-1|332908    |0        |473708|70.27704830824052   |0.0    |
// |origin_weather_SeaLevelPressure-3                 |62543     |0        |473708|13.202859145296259  |0.0    |
// |origin_weather_SeaLevelPressure-2                 |60735     |0        |473708|12.821189424708892  |0.0    |
// |origin_weather_SeaLevelPressure-1                 |59995     |0        |473708|12.664975047919816  |0.0    |
// |origin_weather_SeaLevelPressure-0                 |57625     |0        |473708|12.164666841176421  |0.0    |
// |origin_weather_WindDirection-0                    |8141      |0        |473708|1.7185692451890193  |0.0    |
// |origin_weather_WindDirection-1                    |7656      |0        |473708|1.6161854982394217  |0.0    |
// |origin_weather_WindDirection-3                    |7151      |0        |473708|1.5095797411063356  |0.0    |
// |origin_weather_WindDirection-2                    |7046      |0        |473708|1.4874141876430207  |0.0    |
// |origin_weather_WetBulbFarenheit-0                 |1888      |0        |473708|0.3985577613213203  |0.0    |
// |origin_weather_WetBulbCelsius-0                   |1888      |0        |473708|0.3985577613213203  |0.0    |
// |origin_weather_RelativeHumidity-0                 |1888      |0        |473708|0.3985577613213203  |0.0    |
// |origin_weather_DewPointFarenheit-0                |1868      |0        |473708|0.39433575113783176 |0.0    |
// |origin_weather_DewPointCelsius-0                  |1868      |0        |473708|0.39433575113783176 |0.0    |
// |origin_weather_DryBulbFarenheit-0                 |1644      |0        |473708|0.34704923708275986 |0.0    |
// |origin_weather_DryBulbCelsius-0                   |1644      |0        |473708|0.34704923708275986 |0.0    |
// |origin_weather_StationPressure-0                  |1587      |0        |473708|0.3350165080598174  |0.0    |
// |origin_weather_Altimeter-0                        |1587      |0        |473708|0.3350165080598174  |0.0    |
// |origin_weather_WetBulbFarenheit-3                 |1375      |0        |473708|0.2902632001148387  |0.0    |
// |origin_weather_WetBulbCelsius-3                   |1375      |0        |473708|0.2902632001148387  |0.0    |
// |origin_weather_RelativeHumidity-3                 |1375      |0        |473708|0.2902632001148387  |0.0    |
// |origin_weather_DewPointCelsius-3                  |1338      |0        |473708|0.28245248127538486 |0.0    |
// |origin_weather_DewPointFarenheit-3                |1338      |0        |473708|0.28245248127538486 |0.0    |
// |origin_weather_WetBulbFarenheit-1                 |1334      |0        |473708|0.28160807923868714 |0.0    |
// |origin_weather_WetBulbCelsius-1                   |1334      |0        |473708|0.28160807923868714 |0.0    |
// |origin_weather_RelativeHumidity-1                 |1334      |0        |473708|0.28160807923868714 |0.0    |
// |origin_weather_WetBulbFarenheit-2                 |1332      |0        |473708|0.28118587822033825 |0.0    |
// |origin_weather_WetBulbCelsius-2                   |1332      |0        |473708|0.28118587822033825 |0.0    |
// |origin_weather_RelativeHumidity-2                 |1332      |0        |473708|0.28118587822033825 |0.0    |
// |origin_weather_DewPointFarenheit-1                |1318      |0        |473708|0.27823047109189625 |0.0    |
// |origin_weather_DewPointCelsius-1                  |1318      |0        |473708|0.27823047109189625 |0.0    |
// |origin_weather_DewPointCelsius-2                  |1265      |0        |473708|0.2670421441056516  |0.0    |
// |origin_weather_DewPointFarenheit-2                |1265      |0        |473708|0.2670421441056516  |0.0    |
// |origin_weather_DryBulbCelsius-3                   |1120      |0        |473708|0.2364325702753595  |0.0    |
// |origin_weather_DryBulbFarenheit-3                 |1120      |0        |473708|0.2364325702753595  |0.0    |
// |origin_weather_DryBulbFarenheit-1                 |1118      |0        |473708|0.23601036925701066 |0.0    |
// |origin_weather_DryBulbCelsius-1                   |1118      |0        |473708|0.23601036925701066 |0.0    |
// |origin_weather_StationPressure-1                  |1071      |0        |473708|0.22608864532581252 |0.0    |
// |origin_weather_Altimeter-1                        |1071      |0        |473708|0.22608864532581252 |0.0    |
// |origin_weather_Altimeter-3                        |1040      |0        |473708|0.21954452954140524 |0.0    |
// |origin_weather_StationPressure-3                  |1040      |0        |473708|0.21954452954140524 |0.0    |
// |origin_weather_DryBulbCelsius-2                   |1011      |0        |473708|0.21342261477534683 |0.0    |
// |origin_weather_DryBulbFarenheit-2                 |1011      |0        |473708|0.21342261477534683 |0.0    |
// |origin_weather_StationPressure-2                  |1003      |0        |473708|0.2117338107019514  |0.0    |
// |origin_weather_Altimeter-2                        |1003      |0        |473708|0.2117338107019514  |0.0    |
// |origin_weather_WindSpeed-0                        |573       |0        |473708|0.12096059175694732 |0.0    |
// |origin_weather_feature_pressure_bucket-0          |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_visibility_km-0            |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_hail-0                         |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_visible_moisture-0             |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_precipitation_intensity-0  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_freezing_precip-0              |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_visibility_inverse-0       |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_flight_category-0          |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_most_critical_sky-0        |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_requires_cat_ii-0          |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_visibility_normalized-0    |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_weather_hazard_level-0             |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_has_overcast-0             |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_extracted_codes-0                  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_cloud_risk_score-0         |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_weather_severity_index-0   |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_has_obscured-0             |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_rain-0                         |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_intensity_light-0                  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_obscuration-0                  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_freezing-0                     |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_operations_risk_level-0    |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_intensity_heavy-0                  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_visibility_miles-0         |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_is_very_low_visibility-0   |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_Icing_Risk_Flag-0                  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_hazardous-0                    |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_precipitation-0                |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_is_vfr_conditions-0        |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_lowest_cloud_height-0      |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_visibility_category-0      |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_is_low_visibility-0        |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_weather_intensity-0                |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_snow-0                         |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_has_broken-0               |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_Icing_Risk_Level-0                 |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_has_thunderstorm-0                 |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_is_clear-0                 |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_is_ifr_conditions-0        |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_num_cloud_layers-0         |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_flight_category_ordinal-0  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_ceiling-0                  |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_visibility_risk_score-0    |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_feature_has_low_ceiling-0          |451       |0        |473708|0.09520632963766709 |0.0    |
// |origin_weather_WindSpeed-1                        |304       |0        |473708|0.06417455478902614 |0.0    |
// |origin_weather_WindSpeed-2                        |228       |0        |473708|0.048130916091769615|0.0    |
// |origin_weather_WindSpeed-3                        |192       |0        |473708|0.0405312977614902  |0.0    |
// |origin_weather_feature_visibility_normalized-1    |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_pressure_bucket-1          |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_has_overcast-1             |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_operations_risk_level-1    |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_cloud_risk_score-1         |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_hail-1                         |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_has_obscured-1             |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_weather_severity_index-1   |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_intensity_light-1                  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_visible_moisture-1             |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_freezing-1                     |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_Icing_Risk_Flag-1                  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_intensity_heavy-1                  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_flight_category-1          |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_is_very_low_visibility-1   |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_obscuration-1                  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_hazardous-1                    |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_weather_hazard_level-1             |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_is_vfr_conditions-1        |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_lowest_cloud_height-1      |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_visibility_miles-1         |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_is_low_visibility-1        |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_precipitation-1                |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_snow-1                         |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_visibility_category-1      |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_Icing_Risk_Level-1                 |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_weather_intensity-1                |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_is_clear-1                 |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_has_broken-1               |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_num_cloud_layers-1         |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_thunderstorm-1                 |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_ceiling-1                  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_is_ifr_conditions-1        |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_has_low_ceiling-1          |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_flight_category_ordinal-1  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_visibility_km-1            |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_visibility_risk_score-1    |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_precipitation_intensity-1  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_freezing_precip-1              |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_visibility_inverse-1       |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_requires_cat_ii-1          |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_feature_most_critical_sky-1        |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_extracted_codes-1                  |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_rain-1                         |128       |0        |473708|0.0270208651743268  |0.0    |
// |origin_weather_has_snow-2                         |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_intensity_light-2                  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_Icing_Risk_Level-2                 |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_visibility_category-2      |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_is_clear-2                 |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_freezing-2                     |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_num_cloud_layers-2         |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_pressure_bucket-2          |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_ceiling-2                  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_intensity_heavy-2                  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_has_low_ceiling-2          |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_weather_intensity-2                |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_visibility_km-2            |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_is_very_low_visibility-2   |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_precipitation_intensity-2  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_hail-2                         |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_visibility_inverse-2       |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_hazardous-2                    |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_most_critical_sky-2        |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_has_broken-2               |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_visibility_normalized-2    |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_is_vfr_conditions-2        |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_has_overcast-2             |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_visible_moisture-2             |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_cloud_risk_score-2         |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_thunderstorm-2                 |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_has_obscured-2             |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_flight_category-2          |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_is_ifr_conditions-2        |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_weather_hazard_level-2             |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_flight_category_ordinal-2  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_weather_severity_index-2   |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_visibility_risk_score-2    |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_obscuration-2                  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_freezing_precip-2              |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_visibility_miles-2         |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_feature_requires_cat_ii-2          |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_precipitation-2                |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_extracted_codes-2                  |52        |0        |473708|0.010977226477070263|0.0    |
// |origin_weather_has_rain-2                         |52        |0        |473708|0.010977226477070263|0.0    |
// +--------------------------------------------------+----------+---------+------+--------------------+-------+
// only showing top 200 rows
// [column: string, null_count: bigint ... 4 more fields]

// %%
joinedExplodedDF.select("origin_weather_HourlyPrecip-3").distinct().show()
// Out:
// +-----------------------------+
// |origin_weather_HourlyPrecip-3|
// +-----------------------------+
// |                          0.0|
// |                         0.05|
// |                          0.1|
// |                         0.09|
// |                         0.04|
// |                         0.14|
// |                         0.08|
// |                         0.15|
// |                         0.03|
// |                         0.11|
// |                         0.06|
// |                         0.13|
// |                         0.07|
// |                         0.17|
// |                         1.31|
// |                         0.18|
// |                         0.19|
// |                         0.23|
// |                         NULL|
// |                         0.01|
// +-----------------------------+
// only showing top 20 rows

// %%
import org.apache.spark.sql.functions._

// dfReport = ton DataFrame du tableau ci-dessus (avec la colonne "column")
val featuresDistinct = report
  .select(
    regexp_replace(                             // enlève le suffixe -N
      regexp_replace(                           // enlève le préfixe origin_weather_feature_
        regexp_replace(col("column"), "^origin_weather_feature_", ""),
        "^origin_weather_", ""                  // puis origin_weather_
      ),
      "-\\d+$", ""                              // retire -0 / -1 / -2 / -3 à la fin
    ).alias("feature_base")
  )
  .distinct()
  .orderBy("feature_base")

featuresDistinct.show(truncate = false)
// Out:
// +-----------------------+
// |feature_base           |
// +-----------------------+
// |Altimeter              |
// |CRS_DEP_TIME           |
// |CRS_ELAPSED_TIME       |
// |DEST_AIRPORT_ID        |
// |DEST_WBAN              |
// |DewPointCelsius        |
// |DewPointFarenheit      |
// |DryBulbCelsius         |
// |DryBulbFarenheit       |
// |HourlyPrecip           |
// |Icing_Risk_Flag        |
// |Icing_Risk_Level       |
// |OP_CARRIER_AIRLINE_ID  |
// |ORIGIN_AIRPORT_ID      |
// |ORIGIN_WBAN            |
// |PREV_AIRCRAFT_ARR_DELAY|
// |PressureChange         |
// |PressureTendency       |
// |RelativeHumidity       |
// |SeaLevelPressure       |
// +-----------------------+
// only showing top 20 rows
// featuresDistinct = [feature_base: string]
// [feature_base: string]

// %% [markdown]
// ## Flights NAN

// %%
val rawFlightsDFPath = s"${configuration.common.output.basePath}/common/data/raw_flights.parquet"
val rawFlightsDF = spark.read.parquet(rawFlightsDFPath)
// Out:
// rawFlightsDFPath = /home/jovyan/work/output/common/data/raw_flights.parquet
// rawFlightsDF = [FL_DATE: date, OP_CARRIER_AIRLINE_ID: int ... 10 more fields]
// [FL_DATE: date, OP_CARRIER_AIRLINE_ID: int ... 10 more fields]

// %%
val rawFlightReport = nullNanReport(rawFlightsDF)
rawFlightReport.show(200, truncate = false)
// Out:
// rawFlightReport = [column: string, null_count: bigint ... 4 more fields]
// +---------------------+----------+---------+------+------------------+-------+
// |column               |null_count|nan_count|total |null_pct          |nan_pct|
// +---------------------+----------+---------+------+------------------+-------+
// |CANCELLED            |486133    |0        |486133|100.0             |0.0    |
// |DIVERTED             |486133    |0        |486133|100.0             |0.0    |
// |WEATHER_DELAY        |415225    |0        |486133|85.4138682212481  |0.0    |
// |NAS_DELAY            |415225    |0        |486133|85.4138682212481  |0.0    |
// |ARR_DELAY_NEW        |8108      |0        |486133|1.6678563273836584|0.0    |
// |FL_DATE              |0         |0        |486133|0.0               |0.0    |
// |OP_CARRIER_AIRLINE_ID|0         |0        |486133|0.0               |0.0    |
// |OP_CARRIER_FL_NUM    |0         |0        |486133|0.0               |0.0    |
// |ORIGIN_AIRPORT_ID    |0         |0        |486133|0.0               |0.0    |
// |DEST_AIRPORT_ID      |0         |0        |486133|0.0               |0.0    |
// |CRS_DEP_TIME         |0         |0        |486133|0.0               |0.0    |
// |CRS_ELAPSED_TIME     |0         |0        |486133|0.0               |0.0    |
// +---------------------+----------+---------+------+------------------+-------+
// [column: string, null_count: bigint ... 4 more fields]

// %%
val porcessedFlightsDFPath = s"${configuration.common.output.basePath}/common/data/processed_flights.parquet"
val porcessedFlightsDF = spark.read.parquet(porcessedFlightsDFPath)
// Out:
// porcessedFlightsDFPath = /home/jovyan/work/output/common/data/processed_flights.parquet
// porcessedFlightsDF = [FL_DATE: date, OP_CARRIER_AIRLINE_ID: int ... 135 more fields]
// [FL_DATE: date, OP_CARRIER_AIRLINE_ID: int ... 135 more fields]

// %%
val processedFlightReport = nullNanReport(porcessedFlightsDF)
processedFlightReport.show(200, truncate = false)
// Out:
// processedFlightReport = [column: string, null_count: bigint ... 4 more fields]
// +----------------------------------+----------+---------+------+------------------+-------+
// |column                            |null_count|nan_count|total |null_pct          |nan_pct|
// +----------------------------------+----------+---------+------+------------------+-------+
// |WEATHER_DELAY                     |118446    |0        |138506|85.51687291525276 |0.0    |
// |NAS_DELAY                         |118446    |0        |138506|85.51687291525276 |0.0    |
// |ARR_DELAY_NEW                     |2319      |0        |138506|1.6742956983812975|0.0    |
// |FL_DATE                           |0         |0        |138506|0.0               |0.0    |
// |OP_CARRIER_AIRLINE_ID             |0         |0        |138506|0.0               |0.0    |
// |OP_CARRIER_FL_NUM                 |0         |0        |138506|0.0               |0.0    |
// |ORIGIN_AIRPORT_ID                 |0         |0        |138506|0.0               |0.0    |
// |DEST_AIRPORT_ID                   |0         |0        |138506|0.0               |0.0    |
// |CRS_DEP_TIME                      |0         |0        |138506|0.0               |0.0    |
// |CRS_ELAPSED_TIME                  |0         |0        |138506|0.0               |0.0    |
// |D4                                |0         |0        |138506|0.0               |0.0    |
// |D3                                |0         |0        |138506|0.0               |0.0    |
// |D1                                |0         |0        |138506|0.0               |0.0    |
// |D2_15                             |0         |0        |138506|0.0               |0.0    |
// |D2_30                             |0         |0        |138506|0.0               |0.0    |
// |D2_45                             |0         |0        |138506|0.0               |0.0    |
// |D2_60                             |0         |0        |138506|0.0               |0.0    |
// |D2_90                             |0         |0        |138506|0.0               |0.0    |
// |ORIGIN_WBAN                       |0         |0        |138506|0.0               |0.0    |
// |ORIGIN_TIMEZONE                   |0         |0        |138506|0.0               |0.0    |
// |DEST_WBAN                         |0         |0        |138506|0.0               |0.0    |
// |DEST_TIMEZONE                     |0         |0        |138506|0.0               |0.0    |
// |UTC_CRS_DEP_TIME                  |0         |0        |138506|0.0               |0.0    |
// |UTC_ARR_TIME                      |0         |0        |138506|0.0               |0.0    |
// |UTC_ARR_DATE                      |0         |0        |138506|0.0               |0.0    |
// |CRS_ARR_TIME                      |0         |0        |138506|0.0               |0.0    |
// |CRS_ARR_DATE                      |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_hour              |0         |0        |138506|0.0               |0.0    |
// |feature_utc_arrival_hour          |0         |0        |138506|0.0               |0.0    |
// |feature_utc_arrival_hour_rounded  |0         |0        |138506|0.0               |0.0    |
// |feature_utc_arrival_date          |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_time_period       |0         |0        |138506|0.0               |0.0    |
// |feature_crosses_midnight_local    |0         |0        |138506|0.0               |0.0    |
// |feature_crosses_midnight_utc      |0         |0        |138506|0.0               |0.0    |
// |feature_flight_days_span          |0         |0        |138506|0.0               |0.0    |
// |feature_timezone_difference       |0         |0        |138506|0.0               |0.0    |
// |feature_flies_eastward            |0         |0        |138506|0.0               |0.0    |
// |feature_flies_westward            |0         |0        |138506|0.0               |0.0    |
// |feature_departure_minute          |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_minutes_total     |0         |0        |138506|0.0               |0.0    |
// |feature_crosses_midnight          |0         |0        |138506|0.0               |0.0    |
// |feature_flight_day_of_week        |0         |0        |138506|0.0               |0.0    |
// |feature_departure_hour_decimal    |0         |0        |138506|0.0               |0.0    |
// |feature_flight_timestamp          |0         |0        |138506|0.0               |0.0    |
// |feature_utc_departure_hour        |0         |0        |138506|0.0               |0.0    |
// |feature_flight_quarter_name       |0         |0        |138506|0.0               |0.0    |
// |feature_utc_departure_hour_decimal|0         |0        |138506|0.0               |0.0    |
// |feature_departure_hour            |0         |0        |138506|0.0               |0.0    |
// |feature_minutes_since_midnight    |0         |0        |138506|0.0               |0.0    |
// |feature_departure_quarter_day     |0         |0        |138506|0.0               |0.0    |
// |feature_flight_month              |0         |0        |138506|0.0               |0.0    |
// |feature_utc_departure_hour_rounded|0         |0        |138506|0.0               |0.0    |
// |feature_arrival_minute            |0         |0        |138506|0.0               |0.0    |
// |feature_flight_year               |0         |0        |138506|0.0               |0.0    |
// |feature_flight_day_of_year        |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_time              |0         |0        |138506|0.0               |0.0    |
// |feature_flight_quarter            |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_hour_decimal      |0         |0        |138506|0.0               |0.0    |
// |feature_flight_week_of_year       |0         |0        |138506|0.0               |0.0    |
// |feature_flight_day_of_month       |0         |0        |138506|0.0               |0.0    |
// |feature_departure_quarter_name    |0         |0        |138506|0.0               |0.0    |
// |feature_departure_time_period     |0         |0        |138506|0.0               |0.0    |
// |feature_departure_hour_rounded    |0         |0        |138506|0.0               |0.0    |
// |feature_departure_minutes_total   |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_hour_rounded      |0         |0        |138506|0.0               |0.0    |
// |feature_arrival_date              |0         |0        |138506|0.0               |0.0    |
// |feature_distance_score            |0         |0        |138506|0.0               |0.0    |
// |feature_distance_category         |0         |0        |138506|0.0               |0.0    |
// |feature_carrier_hash              |0         |0        |138506|0.0               |0.0    |
// |feature_route_id                  |0         |0        |138506|0.0               |0.0    |
// |feature_is_likely_domestic        |0         |0        |138506|0.0               |0.0    |
// |feature_is_roundtrip_candidate    |0         |0        |138506|0.0               |0.0    |
// |feature_flight_unique_id          |0         |0        |138506|0.0               |0.0    |
// |feature_is_summer                 |0         |0        |138506|0.0               |0.0    |
// |feature_is_monday                 |0         |0        |138506|0.0               |0.0    |
// |feature_is_evening_rush           |0         |0        |138506|0.0               |0.0    |
// |feature_is_month_start            |0         |0        |138506|0.0               |0.0    |
// |feature_is_extended_weekend       |0         |0        |138506|0.0               |0.0    |
// |feature_is_winter                 |0         |0        |138506|0.0               |0.0    |
// |feature_is_friday                 |0         |0        |138506|0.0               |0.0    |
// |feature_is_spring                 |0         |0        |138506|0.0               |0.0    |
// |feature_is_weekend                |0         |0        |138506|0.0               |0.0    |
// |feature_is_holiday_season         |0         |0        |138506|0.0               |0.0    |
// |feature_is_fall                   |0         |0        |138506|0.0               |0.0    |
// |feature_is_early_morning          |0         |0        |138506|0.0               |0.0    |
// |feature_is_morning_rush           |0         |0        |138506|0.0               |0.0    |
// |feature_is_business_hours         |0         |0        |138506|0.0               |0.0    |
// |feature_is_night_flight           |0         |0        |138506|0.0               |0.0    |
// |feature_is_month_end              |0         |0        |138506|0.0               |0.0    |
// |feature_origin_complexity_score   |0         |0        |138506|0.0               |0.0    |
// |feature_is_westbound              |0         |0        |138506|0.0               |0.0    |
// |feature_dest_complexity_score     |0         |0        |138506|0.0               |0.0    |
// |feature_dest_is_major_hub         |0         |0        |138506|0.0               |0.0    |
// |feature_is_eastbound              |0         |0        |138506|0.0               |0.0    |
// |feature_timezone_diff_proxy       |0         |0        |138506|0.0               |0.0    |
// |feature_origin_is_major_hub       |0         |0        |138506|0.0               |0.0    |
// |feature_is_hub_to_hub             |0         |0        |138506|0.0               |0.0    |
// |feature_flights_on_route          |0         |0        |138506|0.0               |0.0    |
// |feature_carrier_flight_count      |0         |0        |138506|0.0               |0.0    |
// |feature_origin_airport_traffic    |0         |0        |138506|0.0               |0.0    |
// |feature_route_popularity_score    |0         |0        |138506|0.0               |0.0    |
// |feature_carrier_size_category     |0         |0        |138506|0.0               |0.0    |
// |AIRCRAFT_ID                       |0         |0        |138506|0.0               |0.0    |
// |PREV_AIRCRAFT_ARR_DELAY           |0         |0        |138506|0.0               |0.0    |
// |feature_turnaround_buffer         |0         |0        |138506|0.0               |0.0    |
// |IS_PREV_AIRCRAFT_LATE             |0         |0        |138506|0.0               |0.0    |
// |feature_is_tight_turnaround       |0         |0        |138506|0.0               |0.0    |
// |feature_is_very_tight_turnaround  |0         |0        |138506|0.0               |0.0    |
// |feature_turnaround_category       |0         |0        |138506|0.0               |0.0    |
// |label_arr_delay_filled            |0         |0        |138506|0.0               |0.0    |
// |label_nas_delay_filled            |0         |0        |138506|0.0               |0.0    |
// |label_weather_delay_filled        |0         |0        |138506|0.0               |0.0    |
// |label_weather_delay_was_missing   |0         |0        |138506|0.0               |0.0    |
// |label_nas_delay_was_missing       |0         |0        |138506|0.0               |0.0    |
// |label_arr_delay_was_missing       |0         |0        |138506|0.0               |0.0    |
// |label_is_early                    |0         |0        |138506|0.0               |0.0    |
// |label_total_weather_nas_delay     |0         |0        |138506|0.0               |0.0    |
// |label_is_delayed_15min            |0         |0        |138506|0.0               |0.0    |
// |label_has_nas_delay               |0         |0        |138506|0.0               |0.0    |
// |label_is_delayed_30min            |0         |0        |138506|0.0               |0.0    |
// |label_is_delayed_60min            |0         |0        |138506|0.0               |0.0    |
// |label_is_delayed_45min            |0         |0        |138506|0.0               |0.0    |
// |label_is_delayed_90min            |0         |0        |138506|0.0               |0.0    |
// |label_has_weather_delay           |0         |0        |138506|0.0               |0.0    |
// |label_is_on_time                  |0         |0        |138506|0.0               |0.0    |
// |label_has_any_weather_nas_delay   |0         |0        |138506|0.0               |0.0    |
// |feature_avg_delay                 |0         |0        |138506|0.0               |0.0    |
// |feature_num_previous_flights      |0         |0        |138506|0.0               |0.0    |
// |feature_stddev_delay              |0         |0        |138506|0.0               |0.0    |
// |feature_max_delay                 |0         |0        |138506|0.0               |0.0    |
// |feature_min_delay                 |0         |0        |138506|0.0               |0.0    |
// |feature_proportion_delayed_30min  |0         |0        |138506|0.0               |0.0    |
// |feature_proportion_delayed_60min  |0         |0        |138506|0.0               |0.0    |
// |feature_proportion_delayed_15min  |0         |0        |138506|0.0               |0.0    |
// |feature_proportion_delayed_45min  |0         |0        |138506|0.0               |0.0    |
// |feature_proportion_delayed_90min  |0         |0        |138506|0.0               |0.0    |
// |UTC_FL_DATE                       |0         |0        |138506|0.0               |0.0    |
// +----------------------------------+----------+---------+------+------------------+-------+
// [column: string, null_count: bigint ... 4 more fields]

// %%
val joinedDFReport = nullNanReport(joinedDF)
joinedDFReport.show(200, truncate = false)
// Out:
// joinedDFReport = [column: string, null_count: bigint ... 4 more fields]
// +----------------------------------+----------+---------+------+--------+-------+
// |column                            |null_count|nan_count|total |null_pct|nan_pct|
// +----------------------------------+----------+---------+------+--------+-------+
// |CRS_DEP_TIME                      |0         |0        |141717|0.0     |0.0    |
// |CRS_ELAPSED_TIME                  |0         |0        |141717|0.0     |0.0    |
// |DEST_AIRPORT_ID                   |0         |0        |141717|0.0     |0.0    |
// |DEST_WBAN                         |0         |0        |141717|0.0     |0.0    |
// |OP_CARRIER_AIRLINE_ID             |0         |0        |141717|0.0     |0.0    |
// |ORIGIN_AIRPORT_ID                 |0         |0        |141717|0.0     |0.0    |
// |ORIGIN_WBAN                       |0         |0        |141717|0.0     |0.0    |
// |PREV_AIRCRAFT_ARR_DELAY           |0         |0        |141717|0.0     |0.0    |
// |UTC_FL_DATE                       |0         |0        |141717|0.0     |0.0    |
// |feature_arrival_time_period       |0         |0        |141717|0.0     |0.0    |
// |feature_avg_delay                 |0         |0        |141717|0.0     |0.0    |
// |feature_departure_hour_rounded    |0         |0        |141717|0.0     |0.0    |
// |feature_departure_time_period     |0         |0        |141717|0.0     |0.0    |
// |feature_flight_week_of_year       |0         |0        |141717|0.0     |0.0    |
// |feature_turnaround_buffer         |0         |0        |141717|0.0     |0.0    |
// |feature_utc_departure_hour_rounded|0         |0        |141717|0.0     |0.0    |
// |is_delayed                        |0         |0        |141717|0.0     |0.0    |
// |origin_weather_observations       |0         |0        |141717|0.0     |0.0    |
// +----------------------------------+----------+---------+------+--------+-------+
// [column: string, null_count: bigint ... 4 more fields]

// %%
print("Row Flights count = ", rawFlightsDF.count())
print("Processed Flights count = ", porcessedFlightsDF.count())
print("Joinned Flights count = ", joinedDF.count())
print("Joinned Exploded Flights count = ", joinedExplodedDF.count())
// Out:
// (Row Flights count = ,486133)(Processed Flights count = ,138506)(Joinned Flights count = ,141717)(Joinned Exploded Flights count = ,141717)

// %% [markdown]
// ## Probleme Null/NAN dans Flight vient de l'explosion des colonnes weather apres jointure

// %%
import com.flightdelay.features.FeaturePipeline

val explodedDF = FeaturePipeline.explose(joinedDF, experiment)
